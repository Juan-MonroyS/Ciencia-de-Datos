# %% [markdown]
# <a href="https://colab.research.google.com/github/Juan-MonroyS/Ciencia-de-Datos/blob/main/Copy_of_db_SQLite_inventario1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Gestión Básica de Inventario con SQLite3
#
# **Autor: Elias Buitrago B.
# Edición: Juan Camilo Monroy Santana**\
# Bogotá, Colombia \
# Actualizado: 14 Octubre 2025 \
# _Nota: Código ajustado para su ejecución en Google Colaboratory_\

# %% [markdown]
# ## Instalar librerías SQLite3

# %%
# %%shell
# sudo apt-get install sqlite3
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Suggested packages:
#   sqlite3-doc
# The following NEW packages will be installed:
#   sqlite3
# 0 upgraded, 1 newly installed, 0 to remove and 38 not upgraded.
# Need to get 769 kB of archives.
# After this operation, 1,874 kB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy-updates/main amd64 sqlite3 amd64 3.37.2-2ubuntu0.5 [769 kB]
# Fetched 769 kB in 45s (17.1 kB/s)
# debconf: unable to initialize frontend: Dialog
# debconf: (No usable dialog-like program is installed, so the dialog based frontend cannot be used. at /usr/share/perl5/Debconf/FrontEnd/Dialog.pm line 78, <> line 1.)
# debconf: falling back to frontend: Readline
# debconf: unable to initialize frontend: Readline
# debconf: (This frontend requires a controlling tty.)
# debconf: falling back to frontend: Teletype
# dpkg-preconfigure: unable to re-open stdin:
# Selecting previously unselected package sqlite3.
# (Reading database ... 126718 files and directories currently installed.)
# Preparing to unpack .../sqlite3_3.37.2-2ubuntu0.5_amd64.deb ...
# Unpacking sqlite3 (3.37.2-2ubuntu0.5) ...
# Setting up sqlite3 (3.37.2-2ubuntu0.5) ...
# Processing triggers for man-db (2.10.2-1) ...

# %% [markdown]
# ## Crear la base de datos y una tabla de inventario

# %%
import sqlite3
import random

# Crear la base de datos con SQlite
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# %%
# Crear una tabla llamada 'inventario'
c.execute('''
CREATE TABLE inventario (
    id INTEGER PRIMARY KEY,
    nombre TEXT,
    categoria TEXT,
    precio DECIMAL(10, 2),
    cantidad INTEGER,
    proveedor TEXT,
    fecha_ingreso DATE,
    ubicacion TEXT
)
''')

# %%
# Generar datos de ejemplo para la tabla
def generar_producto(id):
    nombres = ["Producto", "Artículo", "Objeto"]
    categorias = ["Electrónica", "Hogar", "Jardín", "Moda", "Deportes"]
    proveedores = ["Proveedor1", "Proveedor2", "Proveedor3"]
    ubicaciones = ["Almacén A", "Almacén B", "Almacén C"]

    nombre = random.choice(nombres) + str(id)
    categoria = random.choice(categorias)
    precio = round(random.uniform(10.0, 500.0), 2)
    cantidad = random.randint(1, 100)
    proveedor = random.choice(proveedores)
    fecha_ingreso = f"2023-{random.randint(1, 12):02d}-{random.randint(1, 28):02d}"
    ubicacion = random.choice(ubicaciones)

    return (id, nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)

# Insertar 1000 productos en la tabla
productos = [generar_producto(i + 1) for i in range(10000)]
c.executemany('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', productos)

# Guardar cambios y cerrar la conexión
conn.commit()
conn.close()

# %%
print("Base de datos creada y poblada con éxito.")
# Out:
# Base de datos creada y poblada con éxito.

# %% [markdown]
# ## Consulta para mostrar todos los productos creados

# %%
import sqlite3

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Consultar todos los productos
c.execute('SELECT * FROM inventario')
productos = c.fetchall()

# Imprimir los productos
for producto in productos:
    print(producto)

# Cerrar la conexión
conn.close()
# Out:
# (1, 'Artículo1', 'Deportes', 26.41, 28, 'Proveedor2', '2023-02-25', 'Almacén C')
# (2, 'Artículo2', 'Hogar', 94.86, 53, 'Proveedor2', '2023-12-24', 'Almacén B')
# (3, 'Artículo3', 'Hogar', 451.54, 26, 'Proveedor2', '2023-11-25', 'Almacén C')
# (4, 'Objeto4', 'Deportes', 47.28, 56, 'Proveedor3', '2023-10-28', 'Almacén B')
# (5, 'Objeto5', 'Hogar', 231.11, 63, 'Proveedor3', '2023-02-13', 'Almacén C')
# (6, 'Producto6', 'Electrónica', 83.6, 67, 'Proveedor1', '2023-03-07', 'Almacén B')
# (7, 'Objeto7', 'Jardín', 123.14, 48, 'Proveedor3', '2023-05-11', 'Almacén A')
# (8, 'Producto8', 'Deportes', 485.5, 70, 'Proveedor3', '2023-09-17', 'Almacén C')
# (9, 'Artículo9', 'Hogar', 21.18, 71, 'Proveedor2', '2023-09-25', 'Almacén A')
# (10, 'Artículo10', 'Hogar', 42.86, 31, 'Proveedor2', '2023-07-10', 'Almacén C')
# (11, 'Producto11', 'Moda', 468.67, 2, 'Proveedor2', '2023-08-13', 'Almacén C')
# (12, 'Objeto12', 'Deportes', 260.05, 27, 'Proveedor3', '2023-12-01', 'Almacén A')
# (13, 'Producto13', 'Moda', 495.97, 1, 'Proveedor3', '2023-03-03', 'Almacén A')
# (14, 'Producto14', 'Deportes', 370.71, 53, 'Proveedor2', '2023-08-02', 'Almacén B')
# (15, 'Artículo15', 'Jardín', 174.1, 85, 'Proveedor3', '2023-09-12', 'Almacén A')
# (16, 'Producto16', 'Moda', 85.67, 6, 'Proveedor2', '2023-11-23', 'Almacén A')
# (17, 'Producto17', 'Hogar', 20.77, 33, 'Proveedor1', '2023-04-01', 'Almacén A')
# (18, 'Objeto18', 'Hogar', 484.41, 31, 'Proveedor3', '2023-04-25', 'Almacén C')
# (19, 'Producto19', 'Deportes', 389.33, 19, 'Proveedor3', '2023-06-01', 'Almacén B')
# (20, 'Producto20', 'Hogar', 79.93, 64, 'Proveedor1', '2023-03-19', 'Almacén A')
# (21, 'Producto21', 'Moda', 425.21, 1, 'Proveedor3', '2023-03-28', 'Almacén A')
# (22, 'Producto22', 'Moda', 388.3, 63, 'Proveedor1', '2023-02-07', 'Almacén C')
# (23, 'Objeto23', 'Moda', 134.5, 36, 'Proveedor2', '2023-06-17', 'Almacén C')
# (24, 'Objeto24', 'Moda', 201.97, 53, 'Proveedor2', '2023-05-19', 'Almacén C')
# (25, 'Artículo25', 'Moda', 39.9, 40, 'Proveedor1', '2023-12-14', 'Almacén B')
# (26, 'Objeto26', 'Deportes', 88.04, 95, 'Proveedor2', '2023-10-03', 'Almacén B')
# (27, 'Artículo27', 'Deportes', 402.5, 28, 'Proveedor1', '2023-10-25', 'Almacén A')
# (28, 'Artículo28', 'Electrónica', 35.48, 39, 'Proveedor1', '2023-01-22', 'Almacén A')
# (29, 'Artículo29', 'Electrónica', 95.46, 66, 'Proveedor2', '2023-12-02', 'Almacén C')
# (30, 'Artículo30', 'Electrónica', 449.51, 88, 'Proveedor3', '2023-02-05', 'Almacén C')
# (31, 'Objeto31', 'Deportes', 417.15, 45, 'Proveedor1', '2023-02-25', 'Almacén B')
# (32, 'Producto32', 'Jardín', 93.46, 59, 'Proveedor2', '2023-09-23', 'Almacén C')
# (33, 'Objeto33', 'Deportes', 286.1, 37, 'Proveedor2', '2023-09-20', 'Almacén C')
# (34, 'Producto34', 'Moda', 467.65, 83, 'Proveedor3', '2023-12-10', 'Almacén C')
# (35, 'Objeto35', 'Deportes', 252.96, 11, 'Proveedor2', '2023-05-03', 'Almacén C')
# (36, 'Artículo36', 'Jardín', 278.11, 78, 'Proveedor3', '2023-08-08', 'Almacén A')
# (37, 'Objeto37', 'Deportes', 170.42, 59, 'Proveedor2', '2023-07-03', 'Almacén B')
# (38, 'Producto38', 'Moda', 174.85, 79, 'Proveedor2', '2023-08-14', 'Almacén B')
# (39, 'Objeto39', 'Moda', 221.7, 2, 'Proveedor1', '2023-10-14', 'Almacén B')
# (40, 'Artículo40', 'Hogar', 207.7, 51, 'Proveedor1', '2023-11-05', 'Almacén B')
# (41, 'Objeto41', 'Moda', 452.91, 28, 'Proveedor3', '2023-09-10', 'Almacén C')
# (42, 'Artículo42', 'Moda', 125.71, 36, 'Proveedor1', '2023-08-10', 'Almacén A')
# (43, 'Producto43', 'Deportes', 212.38, 40, 'Proveedor3', '2023-06-03', 'Almacén C')
# (44, 'Artículo44', 'Deportes', 306.9, 51, 'Proveedor1', '2023-05-04', 'Almacén C')
# (45, 'Producto45', 'Jardín', 222.39, 49, 'Proveedor3', '2023-01-21', 'Almacén A')
# (46, 'Producto46', 'Hogar', 197.99, 76, 'Proveedor2', '2023-08-05', 'Almacén C')
# (47, 'Objeto47', 'Electrónica', 220, 65, 'Proveedor3', '2023-10-02', 'Almacén C')
# (48, 'Objeto48', 'Jardín', 71.75, 43, 'Proveedor2', '2023-02-01', 'Almacén C')
# (49, 'Producto49', 'Moda', 269.65, 82, 'Proveedor2', '2023-03-27', 'Almacén B')
# (50, 'Producto50', 'Jardín', 282.35, 26, 'Proveedor1', '2023-06-03', 'Almacén A')
# (51, 'Artículo51', 'Electrónica', 244.4, 16, 'Proveedor3', '2023-08-18', 'Almacén B')
# (52, 'Producto52', 'Hogar', 451.02, 2, 'Proveedor1', '2023-06-20', 'Almacén C')
# (53, 'Objeto53', 'Deportes', 462.47, 36, 'Proveedor1', '2023-06-11', 'Almacén B')
# (54, 'Artículo54', 'Electrónica', 332.84, 32, 'Proveedor2', '2023-08-22', 'Almacén A')
# (55, 'Artículo55', 'Moda', 390.97, 84, 'Proveedor2', '2023-05-21', 'Almacén A')
# (56, 'Producto56', 'Hogar', 434.35, 79, 'Proveedor2', '2023-03-06', 'Almacén A')
# (57, 'Artículo57', 'Jardín', 81.12, 82, 'Proveedor3', '2023-07-13', 'Almacén B')
# (58, 'Producto58', 'Electrónica', 42.63, 46, 'Proveedor3', '2023-10-07', 'Almacén A')
# (59, 'Objeto59', 'Deportes', 291.27, 26, 'Proveedor1', '2023-05-20', 'Almacén A')
# (60, 'Objeto60', 'Hogar', 281.16, 28, 'Proveedor3', '2023-10-06', 'Almacén C')
# (61, 'Objeto61', 'Deportes', 418.15, 61, 'Proveedor3', '2023-03-01', 'Almacén B')
# (62, 'Producto62', 'Moda', 445.44, 97, 'Proveedor2', '2023-10-22', 'Almacén A')
# (63, 'Producto63', 'Deportes', 138.44, 14, 'Proveedor3', '2023-07-24', 'Almacén A')
# (64, 'Artículo64', 'Electrónica', 356.89, 22, 'Proveedor2', '2023-03-06', 'Almacén A')
# (65, 'Objeto65', 'Hogar', 95.88, 7, 'Proveedor3', '2023-12-03', 'Almacén B')
# (66, 'Producto66', 'Moda', 238.64, 62, 'Proveedor2', '2023-03-02', 'Almacén B')
# (67, 'Objeto67', 'Hogar', 485.18, 4, 'Proveedor2', '2023-04-03', 'Almacén C')
# (68, 'Producto68', 'Hogar', 130.27, 76, 'Proveedor3', '2023-05-12', 'Almacén A')
# (69, 'Objeto69', 'Jardín', 206.11, 41, 'Proveedor2', '2023-04-05', 'Almacén C')
# (70, 'Artículo70', 'Jardín', 143.68, 44, 'Proveedor1', '2023-05-14', 'Almacén A')
# (71, 'Objeto71', 'Jardín', 273.67, 79, 'Proveedor1', '2023-11-14', 'Almacén B')
# (72, 'Producto72', 'Hogar', 434.94, 43, 'Proveedor3', '2023-07-20', 'Almacén C')
# (73, 'Producto73', 'Deportes', 144.7, 96, 'Proveedor2', '2023-06-24', 'Almacén A')
# (74, 'Objeto74', 'Electrónica', 483.94, 1, 'Proveedor3', '2023-07-19', 'Almacén B')
# (75, 'Artículo75', 'Deportes', 59.24, 89, 'Proveedor1', '2023-07-21', 'Almacén C')
# (76, 'Artículo76', 'Moda', 63.94, 74, 'Proveedor2', '2023-08-14', 'Almacén B')
# (77, 'Artículo77', 'Electrónica', 37.53, 88, 'Proveedor1', '2023-03-15', 'Almacén C')
# (78, 'Objeto78', 'Electrónica', 219.8, 29, 'Proveedor2', '2023-03-12', 'Almacén C')
# (79, 'Objeto79', 'Electrónica', 128.2, 6, 'Proveedor1', '2023-09-06', 'Almacén C')
# (80, 'Objeto80', 'Moda', 57.52, 18, 'Proveedor2', '2023-02-10', 'Almacén A')
# (81, 'Producto81', 'Electrónica', 96.43, 77, 'Proveedor3', '2023-07-28', 'Almacén A')
# (82, 'Objeto82', 'Jardín', 272.93, 78, 'Proveedor1', '2023-08-21', 'Almacén B')
# (83, 'Objeto83', 'Deportes', 232.23, 83, 'Proveedor3', '2023-09-28', 'Almacén A')
# (84, 'Artículo84', 'Hogar', 225.61, 60, 'Proveedor1', '2023-05-24', 'Almacén B')
# (85, 'Objeto85', 'Deportes', 260.2, 40, 'Proveedor3', '2023-07-16', 'Almacén A')
# (86, 'Producto86', 'Electrónica', 16.27, 93, 'Proveedor2', '2023-05-19', 'Almacén B')
# (87, 'Objeto87', 'Deportes', 87.75, 50, 'Proveedor3', '2023-04-13', 'Almacén A')
# (88, 'Objeto88', 'Electrónica', 344.01, 6, 'Proveedor3', '2023-05-23', 'Almacén C')
# (89, 'Producto89', 'Deportes', 409.82, 26, 'Proveedor3', '2023-04-11', 'Almacén A')
# (90, 'Producto90', 'Jardín', 349.1, 6, 'Proveedor3', '2023-04-11', 'Almacén C')
# (91, 'Objeto91', 'Jardín', 400.66, 92, 'Proveedor3', '2023-12-15', 'Almacén C')
# (92, 'Producto92', 'Hogar', 174.7, 64, 'Proveedor1', '2023-06-09', 'Almacén A')
# (93, 'Producto93', 'Moda', 228.39, 83, 'Proveedor1', '2023-01-19', 'Almacén B')
# (94, 'Objeto94', 'Deportes', 107.1, 45, 'Proveedor2', '2023-07-23', 'Almacén B')
# (95, 'Objeto95', 'Jardín', 302.29, 96, 'Proveedor1', '2023-02-16', 'Almacén A')
# (96, 'Objeto96', 'Jardín', 412.8, 90, 'Proveedor1', '2023-04-02', 'Almacén A')
# (97, 'Producto97', 'Electrónica', 385.56, 74, 'Proveedor2', '2023-08-01', 'Almacén A')
# (98, 'Producto98', 'Electrónica', 36.69, 94, 'Proveedor2', '2023-12-04', 'Almacén A')
# (99, 'Artículo99', 'Moda', 198.26, 41, 'Proveedor3', '2023-07-16', 'Almacén A')
# (100, 'Artículo100', 'Jardín', 189.95, 2, 'Proveedor2', '2023-08-25', 'Almacén A')
# (101, 'Artículo101', 'Jardín', 465.99, 8, 'Proveedor2', '2023-05-25', 'Almacén B')
# (102, 'Objeto102', 'Deportes', 304.69, 83, 'Proveedor3', '2023-08-23', 'Almacén C')
# (103, 'Producto103', 'Electrónica', 42.87, 17, 'Proveedor1', '2023-09-17', 'Almacén C')
# (104, 'Producto104', 'Deportes', 383.93, 37, 'Proveedor2', '2023-05-02', 'Almacén A')
# (105, 'Artículo105', 'Hogar', 183.41, 69, 'Proveedor2', '2023-06-27', 'Almacén B')
# (106, 'Artículo106', 'Electrónica', 287.7, 66, 'Proveedor1', '2023-02-07', 'Almacén C')
# (107, 'Producto107', 'Electrónica', 138.99, 38, 'Proveedor1', '2023-05-28', 'Almacén C')
# (108, 'Producto108', 'Electrónica', 321.51, 36, 'Proveedor3', '2023-05-21', 'Almacén A')
# (109, 'Artículo109', 'Deportes', 106.99, 85, 'Proveedor1', '2023-02-20', 'Almacén C')
# (110, 'Objeto110', 'Moda', 59.97, 7, 'Proveedor1', '2023-07-04', 'Almacén C')
# (111, 'Artículo111', 'Electrónica', 55.39, 67, 'Proveedor3', '2023-10-17', 'Almacén B')
# (112, 'Artículo112', 'Jardín', 35.81, 70, 'Proveedor2', '2023-06-06', 'Almacén B')
# (113, 'Objeto113', 'Moda', 354.38, 44, 'Proveedor2', '2023-11-28', 'Almacén A')
# (114, 'Objeto114', 'Deportes', 372.17, 70, 'Proveedor1', '2023-05-07', 'Almacén B')
# (115, 'Artículo115', 'Hogar', 332.79, 18, 'Proveedor2', '2023-11-20', 'Almacén A')
# (116, 'Artículo116', 'Jardín', 68.23, 96, 'Proveedor3', '2023-10-03', 'Almacén B')
# (117, 'Objeto117', 'Jardín', 371.32, 55, 'Proveedor3', '2023-01-04', 'Almacén C')
# (118, 'Artículo118', 'Hogar', 477.3, 66, 'Proveedor2', '2023-09-08', 'Almacén C')
# (119, 'Objeto119', 'Deportes', 56.22, 61, 'Proveedor1', '2023-02-22', 'Almacén B')
# (120, 'Artículo120', 'Moda', 39.54, 13, 'Proveedor3', '2023-11-05', 'Almacén B')
# (121, 'Objeto121', 'Deportes', 284.72, 5, 'Proveedor2', '2023-07-28', 'Almacén A')
# (122, 'Objeto122', 'Electrónica', 99.15, 33, 'Proveedor2', '2023-03-10', 'Almacén B')
# (123, 'Artículo123', 'Deportes', 62.29, 98, 'Proveedor3', '2023-09-19', 'Almacén B')
# (124, 'Producto124', 'Jardín', 106.42, 54, 'Proveedor3', '2023-01-16', 'Almacén B')
# (125, 'Producto125', 'Moda', 351.45, 63, 'Proveedor1', '2023-01-04', 'Almacén A')
# (126, 'Objeto126', 'Hogar', 229.36, 74, 'Proveedor1', '2023-12-04', 'Almacén B')
# (127, 'Objeto127', 'Moda', 94.09, 28, 'Proveedor1', '2023-02-19', 'Almacén A')
# (128, 'Objeto128', 'Jardín', 243.3, 57, 'Proveedor1', '2023-11-28', 'Almacén A')
# (129, 'Producto129', 'Electrónica', 382.7, 29, 'Proveedor2', '2023-03-06', 'Almacén C')
# (130, 'Objeto130', 'Electrónica', 223.8, 15, 'Proveedor2', '2023-08-03', 'Almacén C')
# (131, 'Artículo131', 'Electrónica', 467.67, 95, 'Proveedor3', '2023-02-18', 'Almacén A')
# (132, 'Artículo132', 'Electrónica', 290.36, 97, 'Proveedor2', '2023-04-14', 'Almacén C')
# (133, 'Artículo133', 'Moda', 23.08, 80, 'Proveedor1', '2023-10-04', 'Almacén C')
# (134, 'Artículo134', 'Hogar', 294.98, 14, 'Proveedor2', '2023-09-22', 'Almacén C')
# (135, 'Artículo135', 'Deportes', 323.82, 44, 'Proveedor1', '2023-08-18', 'Almacén C')
# (136, 'Producto136', 'Moda', 499.28, 1, 'Proveedor3', '2023-09-27', 'Almacén A')
# (137, 'Producto137', 'Hogar', 368.88, 69, 'Proveedor1', '2023-09-23', 'Almacén C')
# (138, 'Artículo138', 'Hogar', 281.32, 50, 'Proveedor3', '2023-08-19', 'Almacén C')
# (139, 'Producto139', 'Hogar', 497.4, 36, 'Proveedor3', '2023-06-03', 'Almacén B')
# (140, 'Artículo140', 'Moda', 367.33, 19, 'Proveedor2', '2023-10-23', 'Almacén C')
# (141, 'Producto141', 'Moda', 65.92, 44, 'Proveedor2', '2023-11-23', 'Almacén B')
# (142, 'Producto142', 'Jardín', 309.34, 87, 'Proveedor3', '2023-08-27', 'Almacén B')
# (143, 'Producto143', 'Deportes', 413.29, 62, 'Proveedor1', '2023-08-12', 'Almacén A')
# (144, 'Objeto144', 'Deportes', 305.28, 81, 'Proveedor2', '2023-03-22', 'Almacén C')
# (145, 'Producto145', 'Jardín', 120.61, 75, 'Proveedor2', '2023-08-18', 'Almacén C')
# (146, 'Producto146', 'Moda', 356.19, 92, 'Proveedor3', '2023-06-20', 'Almacén B')
# (147, 'Objeto147', 'Jardín', 290.56, 26, 'Proveedor2', '2023-05-26', 'Almacén C')
# (148, 'Producto148', 'Moda', 396.65, 5, 'Proveedor3', '2023-12-21', 'Almacén A')
# (149, 'Objeto149', 'Hogar', 92.33, 46, 'Proveedor1', '2023-12-28', 'Almacén B')
# (150, 'Producto150', 'Deportes', 109.99, 15, 'Proveedor3', '2023-05-25', 'Almacén B')
# (151, 'Producto151', 'Electrónica', 103.92, 34, 'Proveedor1', '2023-06-07', 'Almacén A')
# (152, 'Producto152', 'Deportes', 32.87, 46, 'Proveedor1', '2023-05-28', 'Almacén A')
# (153, 'Objeto153', 'Jardín', 18.39, 67, 'Proveedor3', '2023-06-15', 'Almacén A')
# (154, 'Producto154', 'Hogar', 30.03, 2, 'Proveedor3', '2023-12-13', 'Almacén C')
# (155, 'Objeto155', 'Electrónica', 378.74, 49, 'Proveedor3', '2023-02-12', 'Almacén A')
# (156, 'Artículo156', 'Moda', 229.2, 31, 'Proveedor2', '2023-05-26', 'Almacén A')
# (157, 'Artículo157', 'Hogar', 471.95, 81, 'Proveedor3', '2023-11-27', 'Almacén B')
# (158, 'Artículo158', 'Jardín', 418.55, 3, 'Proveedor2', '2023-02-01', 'Almacén A')
# (159, 'Producto159', 'Electrónica', 407.19, 89, 'Proveedor3', '2023-09-14', 'Almacén B')
# (160, 'Objeto160', 'Deportes', 494.04, 92, 'Proveedor2', '2023-07-14', 'Almacén A')
# (161, 'Producto161', 'Moda', 67.31, 99, 'Proveedor3', '2023-01-21', 'Almacén B')
# (162, 'Objeto162', 'Moda', 91.55, 81, 'Proveedor3', '2023-08-03', 'Almacén C')
# (163, 'Producto163', 'Deportes', 148, 65, 'Proveedor2', '2023-12-12', 'Almacén B')
# (164, 'Artículo164', 'Moda', 491.96, 93, 'Proveedor2', '2023-04-21', 'Almacén A')
# (165, 'Objeto165', 'Moda', 273.53, 3, 'Proveedor1', '2023-12-27', 'Almacén C')
# (166, 'Producto166', 'Moda', 333.24, 90, 'Proveedor1', '2023-05-14', 'Almacén C')
# (167, 'Artículo167', 'Hogar', 222.93, 44, 'Proveedor1', '2023-04-19', 'Almacén C')
# (168, 'Producto168', 'Moda', 410.42, 52, 'Proveedor2', '2023-02-06', 'Almacén A')
# (169, 'Objeto169', 'Jardín', 362.19, 33, 'Proveedor2', '2023-02-02', 'Almacén A')
# (170, 'Producto170', 'Jardín', 438.65, 35, 'Proveedor2', '2023-04-22', 'Almacén C')
# (171, 'Producto171', 'Hogar', 270.71, 100, 'Proveedor2', '2023-05-16', 'Almacén A')
# (172, 'Objeto172', 'Electrónica', 490.71, 70, 'Proveedor1', '2023-04-04', 'Almacén B')
# (173, 'Artículo173', 'Electrónica', 359.07, 19, 'Proveedor2', '2023-12-06', 'Almacén C')
# (174, 'Objeto174', 'Hogar', 268.3, 78, 'Proveedor1', '2023-07-05', 'Almacén B')
# (175, 'Producto175', 'Moda', 475.41, 11, 'Proveedor3', '2023-10-17', 'Almacén C')
# (176, 'Artículo176', 'Hogar', 74.6, 84, 'Proveedor3', '2023-12-18', 'Almacén C')
# (177, 'Objeto177', 'Electrónica', 140.32, 23, 'Proveedor3', '2023-12-12', 'Almacén B')
# (178, 'Objeto178', 'Hogar', 18.03, 55, 'Proveedor3', '2023-11-21', 'Almacén B')
# (179, 'Artículo179', 'Deportes', 183.84, 19, 'Proveedor3', '2023-11-14', 'Almacén B')
# (180, 'Producto180', 'Deportes', 80.16, 2, 'Proveedor3', '2023-07-07', 'Almacén B')
# (181, 'Artículo181', 'Moda', 238.73, 26, 'Proveedor2', '2023-05-23', 'Almacén C')
# (182, 'Producto182', 'Hogar', 439.44, 4, 'Proveedor1', '2023-04-14', 'Almacén A')
# (183, 'Objeto183', 'Hogar', 320.02, 50, 'Proveedor2', '2023-03-28', 'Almacén B')
# (184, 'Objeto184', 'Deportes', 422.96, 60, 'Proveedor1', '2023-02-12', 'Almacén A')
# (185, 'Artículo185', 'Electrónica', 307.34, 32, 'Proveedor2', '2023-03-09', 'Almacén A')
# (186, 'Producto186', 'Hogar', 145.75, 13, 'Proveedor2', '2023-10-09', 'Almacén A')
# (187, 'Artículo187', 'Hogar', 329.03, 25, 'Proveedor2', '2023-07-25', 'Almacén B')
# (188, 'Artículo188', 'Moda', 412.16, 91, 'Proveedor1', '2023-02-28', 'Almacén A')
# (189, 'Artículo189', 'Hogar', 22.05, 17, 'Proveedor3', '2023-09-26', 'Almacén A')
# (190, 'Artículo190', 'Deportes', 269.04, 53, 'Proveedor1', '2023-06-17', 'Almacén A')
# (191, 'Objeto191', 'Moda', 136.84, 84, 'Proveedor2', '2023-01-26', 'Almacén B')
# (192, 'Producto192', 'Deportes', 176.43, 99, 'Proveedor1', '2023-07-21', 'Almacén C')
# (193, 'Objeto193', 'Hogar', 368.2, 39, 'Proveedor1', '2023-05-04', 'Almacén C')
# (194, 'Artículo194', 'Jardín', 381.34, 16, 'Proveedor2', '2023-04-18', 'Almacén B')
# (195, 'Artículo195', 'Moda', 148.29, 47, 'Proveedor2', '2023-09-27', 'Almacén A')
# (196, 'Producto196', 'Electrónica', 176.46, 89, 'Proveedor2', '2023-04-07', 'Almacén A')
# (197, 'Objeto197', 'Moda', 428.07, 8, 'Proveedor1', '2023-07-21', 'Almacén C')
# (198, 'Artículo198', 'Jardín', 447.6, 67, 'Proveedor2', '2023-03-19', 'Almacén C')
# (199, 'Artículo199', 'Electrónica', 202.31, 20, 'Proveedor1', '2023-03-07', 'Almacén C')
# (200, 'Artículo200', 'Moda', 435.21, 41, 'Proveedor2', '2023-12-26', 'Almacén C')
# (201, 'Producto201', 'Hogar', 370.99, 6, 'Proveedor2', '2023-08-05', 'Almacén A')
# (202, 'Producto202', 'Jardín', 361.64, 80, 'Proveedor1', '2023-03-09', 'Almacén B')
# (203, 'Producto203', 'Hogar', 85.06, 73, 'Proveedor2', '2023-05-24', 'Almacén B')
# (204, 'Producto204', 'Deportes', 146.49, 86, 'Proveedor2', '2023-09-19', 'Almacén C')
# (205, 'Producto205', 'Moda', 63.02, 68, 'Proveedor2', '2023-05-08', 'Almacén A')
# (206, 'Producto206', 'Jardín', 260.12, 51, 'Proveedor2', '2023-05-27', 'Almacén B')
# (207, 'Producto207', 'Deportes', 300.67, 54, 'Proveedor2', '2023-01-28', 'Almacén A')
# (208, 'Producto208', 'Hogar', 387.59, 91, 'Proveedor3', '2023-04-28', 'Almacén C')
# (209, 'Objeto209', 'Deportes', 216.77, 18, 'Proveedor3', '2023-10-24', 'Almacén A')
# (210, 'Producto210', 'Jardín', 428.49, 93, 'Proveedor1', '2023-05-26', 'Almacén B')
# (211, 'Producto211', 'Hogar', 121.47, 67, 'Proveedor2', '2023-09-10', 'Almacén B')
# (212, 'Producto212', 'Moda', 268.9, 12, 'Proveedor3', '2023-05-18', 'Almacén A')
# (213, 'Objeto213', 'Hogar', 318.85, 37, 'Proveedor1', '2023-12-21', 'Almacén C')
# (214, 'Producto214', 'Electrónica', 217.1, 29, 'Proveedor3', '2023-08-17', 'Almacén B')
# (215, 'Artículo215', 'Deportes', 410.71, 80, 'Proveedor3', '2023-03-15', 'Almacén B')
# (216, 'Artículo216', 'Moda', 315.73, 41, 'Proveedor1', '2023-04-14', 'Almacén C')
# (217, 'Objeto217', 'Moda', 80.6, 92, 'Proveedor2', '2023-07-20', 'Almacén B')
# (218, 'Artículo218', 'Moda', 23.73, 36, 'Proveedor1', '2023-10-01', 'Almacén B')
# (219, 'Objeto219', 'Jardín', 464.75, 31, 'Proveedor2', '2023-01-28', 'Almacén C')
# (220, 'Producto220', 'Moda', 155.78, 94, 'Proveedor1', '2023-03-19', 'Almacén C')
# (221, 'Artículo221', 'Jardín', 277.27, 64, 'Proveedor1', '2023-04-22', 'Almacén B')
# (222, 'Objeto222', 'Hogar', 329.91, 100, 'Proveedor3', '2023-07-19', 'Almacén B')
# (223, 'Producto223', 'Jardín', 250.8, 74, 'Proveedor3', '2023-01-12', 'Almacén B')
# (224, 'Artículo224', 'Jardín', 226.11, 19, 'Proveedor1', '2023-08-23', 'Almacén C')
# (225, 'Objeto225', 'Hogar', 377.92, 78, 'Proveedor1', '2023-02-24', 'Almacén C')
# (226, 'Objeto226', 'Electrónica', 129.81, 78, 'Proveedor2', '2023-03-07', 'Almacén C')
# (227, 'Producto227', 'Hogar', 25.28, 28, 'Proveedor2', '2023-10-02', 'Almacén B')
# (228, 'Producto228', 'Moda', 230.3, 10, 'Proveedor1', '2023-01-11', 'Almacén B')
# (229, 'Producto229', 'Hogar', 110.32, 33, 'Proveedor1', '2023-01-13', 'Almacén B')
# (230, 'Producto230', 'Deportes', 54.09, 67, 'Proveedor3', '2023-04-05', 'Almacén C')
# (231, 'Producto231', 'Hogar', 433.33, 63, 'Proveedor2', '2023-10-19', 'Almacén B')
# (232, 'Objeto232', 'Moda', 437.98, 90, 'Proveedor1', '2023-07-17', 'Almacén C')
# (233, 'Artículo233', 'Moda', 136.09, 12, 'Proveedor2', '2023-04-11', 'Almacén C')
# (234, 'Producto234', 'Jardín', 470.4, 23, 'Proveedor1', '2023-07-05', 'Almacén B')
# (235, 'Producto235', 'Hogar', 37.25, 17, 'Proveedor3', '2023-01-12', 'Almacén A')
# (236, 'Artículo236', 'Electrónica', 320.86, 47, 'Proveedor1', '2023-05-24', 'Almacén C')
# (237, 'Producto237', 'Hogar', 474.38, 74, 'Proveedor1', '2023-09-02', 'Almacén C')
# (238, 'Objeto238', 'Electrónica', 28.46, 42, 'Proveedor2', '2023-01-10', 'Almacén C')
# (239, 'Objeto239', 'Deportes', 33.71, 70, 'Proveedor2', '2023-05-04', 'Almacén B')
# (240, 'Objeto240', 'Deportes', 175.66, 51, 'Proveedor2', '2023-09-10', 'Almacén C')
# (241, 'Objeto241', 'Hogar', 114.55, 28, 'Proveedor1', '2023-02-25', 'Almacén B')
# (242, 'Producto242', 'Moda', 431.36, 5, 'Proveedor3', '2023-08-21', 'Almacén B')
# (243, 'Producto243', 'Deportes', 229.02, 68, 'Proveedor3', '2023-01-21', 'Almacén A')
# (244, 'Objeto244', 'Moda', 25.63, 61, 'Proveedor2', '2023-11-24', 'Almacén C')
# (245, 'Producto245', 'Moda', 494.24, 9, 'Proveedor1', '2023-08-28', 'Almacén A')
# (246, 'Producto246', 'Jardín', 177.95, 62, 'Proveedor2', '2023-10-10', 'Almacén A')
# (247, 'Objeto247', 'Jardín', 229.6, 28, 'Proveedor1', '2023-05-21', 'Almacén A')
# (248, 'Objeto248', 'Jardín', 154.73, 16, 'Proveedor1', '2023-02-03', 'Almacén B')
# (249, 'Producto249', 'Jardín', 259.27, 93, 'Proveedor1', '2023-08-21', 'Almacén B')
# (250, 'Producto250', 'Deportes', 250.24, 45, 'Proveedor2', '2023-08-09', 'Almacén A')
# (251, 'Artículo251', 'Electrónica', 393.49, 38, 'Proveedor1', '2023-01-10', 'Almacén A')
# (252, 'Objeto252', 'Jardín', 271.13, 58, 'Proveedor2', '2023-07-03', 'Almacén A')
# (253, 'Producto253', 'Electrónica', 375.02, 17, 'Proveedor1', '2023-05-22', 'Almacén C')
# (254, 'Objeto254', 'Deportes', 403.84, 58, 'Proveedor2', '2023-02-23', 'Almacén A')
# (255, 'Artículo255', 'Electrónica', 423.63, 18, 'Proveedor3', '2023-12-01', 'Almacén B')
# (256, 'Objeto256', 'Moda', 57.61, 64, 'Proveedor2', '2023-02-03', 'Almacén B')
# (257, 'Objeto257', 'Moda', 170.05, 56, 'Proveedor3', '2023-12-27', 'Almacén C')
# (258, 'Artículo258', 'Electrónica', 392.63, 82, 'Proveedor3', '2023-06-06', 'Almacén A')
# (259, 'Producto259', 'Hogar', 416.2, 51, 'Proveedor1', '2023-03-10', 'Almacén B')
# (260, 'Objeto260', 'Electrónica', 321.69, 75, 'Proveedor2', '2023-11-10', 'Almacén C')
# (261, 'Objeto261', 'Jardín', 303.81, 32, 'Proveedor3', '2023-04-24', 'Almacén C')
# (262, 'Objeto262', 'Jardín', 421.57, 74, 'Proveedor3', '2023-05-10', 'Almacén C')
# (263, 'Producto263', 'Jardín', 274.06, 58, 'Proveedor3', '2023-05-13', 'Almacén C')
# (264, 'Producto264', 'Moda', 290, 81, 'Proveedor2', '2023-01-20', 'Almacén A')
# (265, 'Producto265', 'Jardín', 321.39, 40, 'Proveedor2', '2023-02-05', 'Almacén B')
# (266, 'Producto266', 'Hogar', 252.96, 29, 'Proveedor2', '2023-12-02', 'Almacén C')
# (267, 'Objeto267', 'Jardín', 243.67, 68, 'Proveedor2', '2023-06-09', 'Almacén B')
# (268, 'Producto268', 'Jardín', 446.17, 29, 'Proveedor1', '2023-05-18', 'Almacén A')
# (269, 'Objeto269', 'Electrónica', 72.21, 27, 'Proveedor1', '2023-02-09', 'Almacén A')
# (270, 'Objeto270', 'Hogar', 102.67, 72, 'Proveedor2', '2023-04-22', 'Almacén C')
# (271, 'Objeto271', 'Hogar', 161.43, 31, 'Proveedor3', '2023-06-09', 'Almacén B')
# (272, 'Objeto272', 'Jardín', 377.05, 74, 'Proveedor1', '2023-06-13', 'Almacén A')
# (273, 'Artículo273', 'Jardín', 141.5, 66, 'Proveedor3', '2023-02-08', 'Almacén A')
# (274, 'Producto274', 'Jardín', 463.34, 17, 'Proveedor2', '2023-05-15', 'Almacén A')
# (275, 'Producto275', 'Electrónica', 398.13, 40, 'Proveedor3', '2023-10-20', 'Almacén A')
# (276, 'Artículo276', 'Deportes', 303.61, 14, 'Proveedor1', '2023-09-11', 'Almacén B')
# (277, 'Objeto277', 'Jardín', 323.3, 1, 'Proveedor1', '2023-07-21', 'Almacén C')
# (278, 'Producto278', 'Hogar', 259.8, 34, 'Proveedor3', '2023-06-25', 'Almacén C')
# (279, 'Artículo279', 'Jardín', 135.28, 98, 'Proveedor3', '2023-10-22', 'Almacén C')
# (280, 'Objeto280', 'Electrónica', 54.69, 55, 'Proveedor1', '2023-10-28', 'Almacén A')
# (281, 'Objeto281', 'Hogar', 100.67, 51, 'Proveedor3', '2023-04-02', 'Almacén B')
# (282, 'Artículo282', 'Moda', 192.34, 22, 'Proveedor1', '2023-04-11', 'Almacén A')
# (283, 'Objeto283', 'Electrónica', 480.37, 69, 'Proveedor3', '2023-05-02', 'Almacén B')
# (284, 'Objeto284', 'Deportes', 453.2, 24, 'Proveedor2', '2023-02-18', 'Almacén A')
# (285, 'Producto285', 'Jardín', 458.2, 56, 'Proveedor3', '2023-11-01', 'Almacén A')
# (286, 'Artículo286', 'Moda', 454.59, 51, 'Proveedor3', '2023-02-27', 'Almacén A')
# (287, 'Objeto287', 'Jardín', 255.31, 76, 'Proveedor2', '2023-08-16', 'Almacén A')
# (288, 'Objeto288', 'Hogar', 23.1, 11, 'Proveedor2', '2023-04-28', 'Almacén A')
# (289, 'Objeto289', 'Deportes', 125.24, 12, 'Proveedor1', '2023-03-16', 'Almacén B')
# (290, 'Objeto290', 'Deportes', 138.86, 94, 'Proveedor3', '2023-01-16', 'Almacén C')
# (291, 'Artículo291', 'Moda', 423.5, 68, 'Proveedor3', '2023-06-07', 'Almacén B')
# (292, 'Producto292', 'Jardín', 309.72, 13, 'Proveedor3', '2023-08-18', 'Almacén C')
# (293, 'Artículo293', 'Deportes', 97.49, 75, 'Proveedor1', '2023-05-22', 'Almacén C')
# (294, 'Producto294', 'Electrónica', 85.46, 73, 'Proveedor2', '2023-04-04', 'Almacén A')
# (295, 'Objeto295', 'Moda', 220.26, 47, 'Proveedor1', '2023-07-17', 'Almacén C')
# (296, 'Producto296', 'Jardín', 170.29, 39, 'Proveedor3', '2023-04-22', 'Almacén C')
# (297, 'Objeto297', 'Jardín', 409.19, 21, 'Proveedor2', '2023-10-27', 'Almacén C')
# (298, 'Producto298', 'Moda', 26.89, 95, 'Proveedor1', '2023-09-18', 'Almacén C')
# (299, 'Artículo299', 'Jardín', 73.85, 9, 'Proveedor1', '2023-11-01', 'Almacén A')
# (300, 'Artículo300', 'Deportes', 212.29, 22, 'Proveedor1', '2023-08-24', 'Almacén B')
# (301, 'Artículo301', 'Electrónica', 454.5, 80, 'Proveedor3', '2023-04-01', 'Almacén C')
# (302, 'Producto302', 'Jardín', 39.67, 5, 'Proveedor3', '2023-08-05', 'Almacén A')
# (303, 'Objeto303', 'Deportes', 286.14, 85, 'Proveedor3', '2023-11-19', 'Almacén A')
# (304, 'Producto304', 'Hogar', 117.9, 19, 'Proveedor3', '2023-10-05', 'Almacén C')
# (305, 'Artículo305', 'Electrónica', 298.4, 15, 'Proveedor2', '2023-02-21', 'Almacén A')
# (306, 'Objeto306', 'Deportes', 474.94, 48, 'Proveedor3', '2023-10-12', 'Almacén A')
# (307, 'Producto307', 'Electrónica', 304.79, 34, 'Proveedor1', '2023-09-09', 'Almacén A')
# (308, 'Producto308', 'Jardín', 445.16, 4, 'Proveedor3', '2023-03-07', 'Almacén B')
# (309, 'Artículo309', 'Electrónica', 284.53, 31, 'Proveedor3', '2023-08-19', 'Almacén C')
# (310, 'Objeto310', 'Hogar', 149.02, 84, 'Proveedor1', '2023-03-21', 'Almacén B')
# (311, 'Producto311', 'Moda', 102.81, 92, 'Proveedor3', '2023-02-06', 'Almacén B')
# (312, 'Producto312', 'Hogar', 173.67, 22, 'Proveedor3', '2023-10-14', 'Almacén C')
# (313, 'Producto313', 'Electrónica', 176.24, 86, 'Proveedor3', '2023-01-17', 'Almacén C')
# (314, 'Producto314', 'Hogar', 487.94, 21, 'Proveedor1', '2023-08-10', 'Almacén B')
# (315, 'Artículo315', 'Jardín', 496.84, 7, 'Proveedor3', '2023-04-23', 'Almacén C')
# (316, 'Artículo316', 'Moda', 110.67, 96, 'Proveedor3', '2023-04-24', 'Almacén B')
# (317, 'Objeto317', 'Deportes', 39.04, 61, 'Proveedor1', '2023-09-08', 'Almacén C')
# (318, 'Producto318', 'Deportes', 369.39, 18, 'Proveedor3', '2023-09-16', 'Almacén B')
# (319, 'Producto319', 'Moda', 197.01, 58, 'Proveedor1', '2023-05-13', 'Almacén C')
# (320, 'Objeto320', 'Electrónica', 294.88, 93, 'Proveedor1', '2023-04-16', 'Almacén A')
# (321, 'Objeto321', 'Deportes', 320.41, 81, 'Proveedor2', '2023-04-19', 'Almacén A')
# (322, 'Artículo322', 'Hogar', 89.67, 35, 'Proveedor3', '2023-03-24', 'Almacén B')
# (323, 'Artículo323', 'Electrónica', 98.95, 2, 'Proveedor2', '2023-08-15', 'Almacén C')
# (324, 'Producto324', 'Hogar', 97.25, 16, 'Proveedor2', '2023-11-28', 'Almacén B')
# (325, 'Artículo325', 'Deportes', 443.92, 79, 'Proveedor2', '2023-04-21', 'Almacén C')
# (326, 'Producto326', 'Jardín', 97.91, 90, 'Proveedor3', '2023-09-08', 'Almacén C')
# (327, 'Producto327', 'Electrónica', 242.33, 75, 'Proveedor1', '2023-12-03', 'Almacén B')
# (328, 'Objeto328', 'Deportes', 337.47, 41, 'Proveedor2', '2023-09-14', 'Almacén A')
# (329, 'Producto329', 'Deportes', 358.19, 83, 'Proveedor2', '2023-05-13', 'Almacén B')
# (330, 'Objeto330', 'Jardín', 269.6, 76, 'Proveedor1', '2023-10-19', 'Almacén B')
# (331, 'Objeto331', 'Deportes', 15.63, 10, 'Proveedor2', '2023-10-06', 'Almacén B')
# (332, 'Artículo332', 'Moda', 363.8, 27, 'Proveedor3', '2023-05-10', 'Almacén B')
# (333, 'Objeto333', 'Deportes', 47.08, 22, 'Proveedor2', '2023-09-24', 'Almacén C')
# (334, 'Objeto334', 'Moda', 372.09, 55, 'Proveedor3', '2023-07-16', 'Almacén B')
# (335, 'Objeto335', 'Deportes', 412.18, 72, 'Proveedor3', '2023-02-11', 'Almacén B')
# (336, 'Objeto336', 'Jardín', 113.21, 54, 'Proveedor3', '2023-08-11', 'Almacén B')
# (337, 'Objeto337', 'Deportes', 349.56, 81, 'Proveedor2', '2023-01-08', 'Almacén B')
# (338, 'Objeto338', 'Deportes', 212.31, 1, 'Proveedor3', '2023-11-01', 'Almacén A')
# (339, 'Producto339', 'Jardín', 148.21, 72, 'Proveedor3', '2023-10-19', 'Almacén C')
# (340, 'Producto340', 'Hogar', 284.14, 14, 'Proveedor1', '2023-05-14', 'Almacén B')
# (341, 'Artículo341', 'Deportes', 93.55, 78, 'Proveedor3', '2023-02-11', 'Almacén C')
# (342, 'Artículo342', 'Deportes', 177.3, 60, 'Proveedor1', '2023-05-06', 'Almacén A')
# (343, 'Objeto343', 'Jardín', 212.63, 33, 'Proveedor1', '2023-07-24', 'Almacén C')
# (344, 'Producto344', 'Electrónica', 67.81, 82, 'Proveedor3', '2023-05-07', 'Almacén A')
# (345, 'Artículo345', 'Jardín', 436.49, 90, 'Proveedor1', '2023-05-19', 'Almacén A')
# (346, 'Objeto346', 'Electrónica', 238.08, 99, 'Proveedor1', '2023-12-24', 'Almacén B')
# (347, 'Producto347', 'Electrónica', 182.84, 93, 'Proveedor1', '2023-01-26', 'Almacén A')
# (348, 'Objeto348', 'Deportes', 48.02, 45, 'Proveedor3', '2023-12-18', 'Almacén B')
# (349, 'Producto349', 'Moda', 394.63, 97, 'Proveedor2', '2023-09-04', 'Almacén A')
# (350, 'Objeto350', 'Moda', 93.59, 49, 'Proveedor3', '2023-12-09', 'Almacén A')
# (351, 'Producto351', 'Electrónica', 276.56, 27, 'Proveedor1', '2023-01-05', 'Almacén A')
# (352, 'Objeto352', 'Hogar', 157.91, 32, 'Proveedor2', '2023-02-02', 'Almacén A')
# (353, 'Objeto353', 'Deportes', 169.91, 57, 'Proveedor2', '2023-02-04', 'Almacén C')
# (354, 'Objeto354', 'Deportes', 414.13, 19, 'Proveedor1', '2023-04-01', 'Almacén C')
# (355, 'Artículo355', 'Electrónica', 360.16, 70, 'Proveedor1', '2023-12-17', 'Almacén B')
# (356, 'Objeto356', 'Moda', 424.77, 53, 'Proveedor2', '2023-06-15', 'Almacén A')
# (357, 'Artículo357', 'Hogar', 89.58, 42, 'Proveedor1', '2023-06-26', 'Almacén B')
# (358, 'Objeto358', 'Moda', 79.23, 71, 'Proveedor3', '2023-01-15', 'Almacén A')
# (359, 'Artículo359', 'Deportes', 386.79, 38, 'Proveedor2', '2023-03-23', 'Almacén B')
# (360, 'Producto360', 'Deportes', 185.39, 80, 'Proveedor2', '2023-04-13', 'Almacén B')
# (361, 'Producto361', 'Hogar', 361.87, 88, 'Proveedor1', '2023-04-22', 'Almacén C')
# (362, 'Producto362', 'Hogar', 451.3, 11, 'Proveedor2', '2023-01-23', 'Almacén B')
# (363, 'Producto363', 'Hogar', 140.08, 98, 'Proveedor3', '2023-04-21', 'Almacén C')
# (364, 'Objeto364', 'Moda', 151.94, 74, 'Proveedor1', '2023-04-17', 'Almacén C')
# (365, 'Producto365', 'Hogar', 491.89, 53, 'Proveedor1', '2023-07-22', 'Almacén C')
# (366, 'Artículo366', 'Hogar', 131.98, 52, 'Proveedor3', '2023-07-26', 'Almacén B')
# (367, 'Producto367', 'Deportes', 387.71, 72, 'Proveedor1', '2023-08-04', 'Almacén C')
# (368, 'Producto368', 'Hogar', 54.51, 45, 'Proveedor1', '2023-06-21', 'Almacén B')
# (369, 'Producto369', 'Deportes', 382.26, 87, 'Proveedor2', '2023-03-09', 'Almacén C')
# (370, 'Artículo370', 'Electrónica', 111.94, 36, 'Proveedor2', '2023-05-07', 'Almacén A')
# (371, 'Producto371', 'Hogar', 419.77, 72, 'Proveedor3', '2023-09-16', 'Almacén B')
# (372, 'Artículo372', 'Electrónica', 263.78, 12, 'Proveedor1', '2023-04-03', 'Almacén B')
# (373, 'Producto373', 'Jardín', 318.71, 6, 'Proveedor2', '2023-01-06', 'Almacén A')
# (374, 'Objeto374', 'Jardín', 443.36, 20, 'Proveedor1', '2023-06-08', 'Almacén C')
# (375, 'Objeto375', 'Moda', 45.93, 24, 'Proveedor3', '2023-08-11', 'Almacén C')
# (376, 'Producto376', 'Hogar', 253.3, 72, 'Proveedor2', '2023-06-25', 'Almacén B')
# (377, 'Objeto377', 'Jardín', 222.2, 46, 'Proveedor2', '2023-02-01', 'Almacén B')
# (378, 'Producto378', 'Moda', 187.85, 45, 'Proveedor1', '2023-11-15', 'Almacén B')
# (379, 'Producto379', 'Electrónica', 276.68, 82, 'Proveedor3', '2023-01-26', 'Almacén C')
# (380, 'Artículo380', 'Deportes', 378.74, 8, 'Proveedor3', '2023-04-10', 'Almacén B')
# (381, 'Objeto381', 'Moda', 249.51, 25, 'Proveedor1', '2023-05-25', 'Almacén B')
# (382, 'Objeto382', 'Moda', 478.06, 44, 'Proveedor2', '2023-11-11', 'Almacén C')
# (383, 'Producto383', 'Hogar', 366.09, 27, 'Proveedor1', '2023-09-18', 'Almacén B')
# (384, 'Objeto384', 'Hogar', 228.18, 87, 'Proveedor2', '2023-03-11', 'Almacén A')
# (385, 'Producto385', 'Electrónica', 144.63, 76, 'Proveedor3', '2023-09-24', 'Almacén A')
# (386, 'Artículo386', 'Deportes', 175.11, 31, 'Proveedor2', '2023-09-21', 'Almacén A')
# (387, 'Artículo387', 'Electrónica', 89.12, 20, 'Proveedor2', '2023-06-21', 'Almacén B')
# (388, 'Artículo388', 'Electrónica', 201.45, 46, 'Proveedor1', '2023-04-26', 'Almacén C')
# (389, 'Artículo389', 'Deportes', 73.8, 43, 'Proveedor2', '2023-11-08', 'Almacén B')
# (390, 'Producto390', 'Moda', 243.16, 38, 'Proveedor1', '2023-04-28', 'Almacén C')
# (391, 'Objeto391', 'Electrónica', 39.47, 50, 'Proveedor2', '2023-01-20', 'Almacén A')
# (392, 'Objeto392', 'Jardín', 389.72, 54, 'Proveedor3', '2023-05-03', 'Almacén A')
# (393, 'Artículo393', 'Electrónica', 218.24, 60, 'Proveedor1', '2023-12-13', 'Almacén C')
# (394, 'Producto394', 'Moda', 348, 54, 'Proveedor1', '2023-06-18', 'Almacén B')
# (395, 'Producto395', 'Hogar', 499.32, 19, 'Proveedor2', '2023-02-13', 'Almacén B')
# (396, 'Objeto396', 'Deportes', 413.07, 13, 'Proveedor3', '2023-07-04', 'Almacén B')
# (397, 'Producto397', 'Electrónica', 366.79, 99, 'Proveedor2', '2023-02-23', 'Almacén B')
# (398, 'Producto398', 'Deportes', 337.87, 29, 'Proveedor2', '2023-01-17', 'Almacén B')
# (399, 'Artículo399', 'Jardín', 211.21, 64, 'Proveedor3', '2023-02-28', 'Almacén B')
# (400, 'Objeto400', 'Hogar', 84.33, 3, 'Proveedor3', '2023-09-18', 'Almacén B')
# (401, 'Objeto401', 'Deportes', 125.82, 77, 'Proveedor3', '2023-08-06', 'Almacén B')
# (402, 'Objeto402', 'Jardín', 184.03, 75, 'Proveedor3', '2023-03-17', 'Almacén A')
# (403, 'Producto403', 'Deportes', 373.84, 29, 'Proveedor2', '2023-08-07', 'Almacén C')
# (404, 'Producto404', 'Moda', 232.02, 53, 'Proveedor2', '2023-02-12', 'Almacén B')
# (405, 'Producto405', 'Moda', 450.21, 47, 'Proveedor2', '2023-04-25', 'Almacén C')
# (406, 'Producto406', 'Jardín', 124.92, 79, 'Proveedor1', '2023-04-02', 'Almacén C')
# (407, 'Objeto407', 'Electrónica', 383.75, 25, 'Proveedor2', '2023-03-04', 'Almacén A')
# (408, 'Artículo408', 'Hogar', 341.28, 8, 'Proveedor2', '2023-04-20', 'Almacén C')
# (409, 'Producto409', 'Hogar', 151.67, 33, 'Proveedor2', '2023-01-08', 'Almacén B')
# (410, 'Objeto410', 'Hogar', 206.43, 38, 'Proveedor1', '2023-11-17', 'Almacén C')
# (411, 'Objeto411', 'Deportes', 203.89, 41, 'Proveedor1', '2023-04-26', 'Almacén B')
# (412, 'Artículo412', 'Jardín', 408.12, 52, 'Proveedor3', '2023-08-04', 'Almacén C')
# (413, 'Objeto413', 'Jardín', 150.15, 77, 'Proveedor1', '2023-12-21', 'Almacén A')
# (414, 'Producto414', 'Deportes', 485.72, 53, 'Proveedor1', '2023-05-25', 'Almacén C')
# (415, 'Producto415', 'Electrónica', 403.32, 36, 'Proveedor2', '2023-08-11', 'Almacén C')
# (416, 'Objeto416', 'Moda', 97.06, 26, 'Proveedor2', '2023-08-18', 'Almacén C')
# (417, 'Artículo417', 'Electrónica', 359.4, 20, 'Proveedor3', '2023-06-02', 'Almacén C')
# (418, 'Artículo418', 'Electrónica', 237.07, 59, 'Proveedor3', '2023-12-21', 'Almacén B')
# (419, 'Objeto419', 'Hogar', 157.61, 10, 'Proveedor2', '2023-08-25', 'Almacén C')
# (420, 'Producto420', 'Moda', 486.42, 68, 'Proveedor3', '2023-04-17', 'Almacén C')
# (421, 'Objeto421', 'Electrónica', 201.31, 18, 'Proveedor2', '2023-01-13', 'Almacén B')
# (422, 'Producto422', 'Electrónica', 138.69, 48, 'Proveedor2', '2023-11-25', 'Almacén B')
# (423, 'Producto423', 'Moda', 288.53, 25, 'Proveedor3', '2023-12-15', 'Almacén B')
# (424, 'Artículo424', 'Jardín', 42.81, 60, 'Proveedor2', '2023-08-26', 'Almacén C')
# (425, 'Artículo425', 'Moda', 13.4, 68, 'Proveedor3', '2023-04-19', 'Almacén C')
# (426, 'Artículo426', 'Electrónica', 394.81, 5, 'Proveedor3', '2023-08-17', 'Almacén C')
# (427, 'Producto427', 'Jardín', 486.66, 27, 'Proveedor2', '2023-08-06', 'Almacén C')
# (428, 'Producto428', 'Hogar', 224.99, 95, 'Proveedor2', '2023-06-05', 'Almacén A')
# (429, 'Artículo429', 'Deportes', 126.72, 15, 'Proveedor2', '2023-09-21', 'Almacén A')
# (430, 'Objeto430', 'Hogar', 34.61, 57, 'Proveedor3', '2023-04-01', 'Almacén C')
# (431, 'Producto431', 'Moda', 102.71, 13, 'Proveedor1', '2023-09-03', 'Almacén A')
# (432, 'Producto432', 'Electrónica', 244.8, 3, 'Proveedor3', '2023-02-28', 'Almacén C')
# (433, 'Producto433', 'Electrónica', 288.43, 44, 'Proveedor2', '2023-12-04', 'Almacén A')
# (434, 'Objeto434', 'Electrónica', 314.98, 35, 'Proveedor3', '2023-01-03', 'Almacén B')
# (435, 'Objeto435', 'Jardín', 35.78, 43, 'Proveedor1', '2023-11-27', 'Almacén C')
# (436, 'Producto436', 'Moda', 164.79, 29, 'Proveedor3', '2023-04-23', 'Almacén B')
# (437, 'Objeto437', 'Deportes', 314.59, 26, 'Proveedor3', '2023-12-26', 'Almacén A')
# (438, 'Producto438', 'Moda', 392.91, 13, 'Proveedor2', '2023-12-05', 'Almacén A')
# (439, 'Artículo439', 'Deportes', 237.67, 34, 'Proveedor3', '2023-05-14', 'Almacén B')
# (440, 'Producto440', 'Jardín', 446.83, 53, 'Proveedor3', '2023-03-20', 'Almacén C')
# (441, 'Producto441', 'Electrónica', 261.52, 44, 'Proveedor2', '2023-11-07', 'Almacén B')
# (442, 'Objeto442', 'Deportes', 331.08, 68, 'Proveedor2', '2023-01-18', 'Almacén A')
# (443, 'Producto443', 'Moda', 144.52, 86, 'Proveedor2', '2023-06-22', 'Almacén B')
# (444, 'Producto444', 'Deportes', 189.67, 97, 'Proveedor3', '2023-02-13', 'Almacén A')
# (445, 'Producto445', 'Moda', 164.01, 34, 'Proveedor1', '2023-11-10', 'Almacén C')
# (446, 'Artículo446', 'Deportes', 144.23, 4, 'Proveedor3', '2023-06-17', 'Almacén C')
# (447, 'Objeto447', 'Electrónica', 83.23, 62, 'Proveedor3', '2023-03-27', 'Almacén A')
# (448, 'Objeto448', 'Moda', 314.76, 45, 'Proveedor1', '2023-11-06', 'Almacén A')
# (449, 'Producto449', 'Jardín', 179.44, 20, 'Proveedor1', '2023-12-09', 'Almacén B')
# (450, 'Artículo450', 'Jardín', 445.83, 32, 'Proveedor3', '2023-12-10', 'Almacén C')
# (451, 'Objeto451', 'Deportes', 377.43, 51, 'Proveedor1', '2023-03-04', 'Almacén C')
# (452, 'Artículo452', 'Deportes', 86.15, 47, 'Proveedor1', '2023-06-26', 'Almacén B')
# (453, 'Objeto453', 'Jardín', 202.08, 95, 'Proveedor3', '2023-10-20', 'Almacén B')
# (454, 'Artículo454', 'Moda', 427.83, 99, 'Proveedor1', '2023-07-04', 'Almacén A')
# (455, 'Producto455', 'Hogar', 271.13, 9, 'Proveedor1', '2023-07-12', 'Almacén B')
# (456, 'Producto456', 'Jardín', 247.84, 74, 'Proveedor3', '2023-09-10', 'Almacén B')
# (457, 'Artículo457', 'Hogar', 477.26, 35, 'Proveedor2', '2023-10-12', 'Almacén A')
# (458, 'Artículo458', 'Jardín', 316.63, 52, 'Proveedor3', '2023-01-10', 'Almacén C')
# (459, 'Producto459', 'Hogar', 20.63, 28, 'Proveedor3', '2023-06-12', 'Almacén C')
# (460, 'Objeto460', 'Jardín', 102.81, 38, 'Proveedor2', '2023-05-28', 'Almacén C')
# (461, 'Objeto461', 'Deportes', 102.08, 16, 'Proveedor2', '2023-07-15', 'Almacén C')
# (462, 'Objeto462', 'Moda', 57.44, 46, 'Proveedor1', '2023-02-10', 'Almacén B')
# (463, 'Objeto463', 'Moda', 230.15, 20, 'Proveedor2', '2023-10-02', 'Almacén A')
# (464, 'Objeto464', 'Moda', 429.78, 40, 'Proveedor3', '2023-10-22', 'Almacén A')
# (465, 'Producto465', 'Hogar', 304.32, 29, 'Proveedor3', '2023-07-17', 'Almacén A')
# (466, 'Producto466', 'Deportes', 331.68, 17, 'Proveedor3', '2023-05-18', 'Almacén A')
# (467, 'Objeto467', 'Deportes', 43.25, 60, 'Proveedor3', '2023-09-04', 'Almacén B')
# (468, 'Producto468', 'Moda', 389.94, 63, 'Proveedor1', '2023-11-13', 'Almacén B')
# (469, 'Artículo469', 'Electrónica', 62.44, 19, 'Proveedor3', '2023-03-20', 'Almacén A')
# (470, 'Objeto470', 'Hogar', 175.44, 49, 'Proveedor3', '2023-12-18', 'Almacén B')
# (471, 'Artículo471', 'Electrónica', 358.54, 60, 'Proveedor1', '2023-06-22', 'Almacén C')
# (472, 'Artículo472', 'Jardín', 205.41, 32, 'Proveedor2', '2023-11-12', 'Almacén C')
# (473, 'Artículo473', 'Hogar', 213.29, 31, 'Proveedor1', '2023-12-24', 'Almacén A')
# (474, 'Objeto474', 'Hogar', 192.15, 87, 'Proveedor3', '2023-03-08', 'Almacén A')
# (475, 'Objeto475', 'Electrónica', 243.94, 61, 'Proveedor2', '2023-06-21', 'Almacén A')
# (476, 'Objeto476', 'Jardín', 352.47, 14, 'Proveedor3', '2023-10-04', 'Almacén C')
# (477, 'Artículo477', 'Hogar', 152.39, 58, 'Proveedor1', '2023-04-19', 'Almacén A')
# (478, 'Objeto478', 'Moda', 69.7, 32, 'Proveedor2', '2023-04-14', 'Almacén B')
# (479, 'Artículo479', 'Deportes', 244.34, 9, 'Proveedor2', '2023-12-15', 'Almacén B')
# (480, 'Objeto480', 'Moda', 152.23, 12, 'Proveedor1', '2023-01-07', 'Almacén A')
# (481, 'Producto481', 'Electrónica', 203.58, 84, 'Proveedor1', '2023-08-10', 'Almacén A')
# (482, 'Artículo482', 'Deportes', 337.92, 28, 'Proveedor2', '2023-12-02', 'Almacén B')
# (483, 'Objeto483', 'Hogar', 224.63, 22, 'Proveedor1', '2023-08-16', 'Almacén B')
# (484, 'Producto484', 'Jardín', 35.53, 65, 'Proveedor3', '2023-03-23', 'Almacén A')
# (485, 'Artículo485', 'Jardín', 15.7, 44, 'Proveedor1', '2023-06-28', 'Almacén B')
# (486, 'Artículo486', 'Electrónica', 81.59, 26, 'Proveedor1', '2023-10-26', 'Almacén B')
# (487, 'Objeto487', 'Hogar', 207.06, 73, 'Proveedor1', '2023-07-18', 'Almacén C')
# (488, 'Producto488', 'Jardín', 196.14, 6, 'Proveedor2', '2023-09-01', 'Almacén A')
# (489, 'Objeto489', 'Hogar', 289.71, 48, 'Proveedor3', '2023-05-06', 'Almacén A')
# (490, 'Producto490', 'Deportes', 230.2, 11, 'Proveedor2', '2023-08-04', 'Almacén A')
# (491, 'Producto491', 'Hogar', 416.95, 29, 'Proveedor1', '2023-05-10', 'Almacén B')
# (492, 'Artículo492', 'Jardín', 41.46, 24, 'Proveedor2', '2023-10-18', 'Almacén C')
# (493, 'Producto493', 'Jardín', 120.59, 7, 'Proveedor2', '2023-07-13', 'Almacén A')
# (494, 'Artículo494', 'Electrónica', 175.18, 98, 'Proveedor2', '2023-11-27', 'Almacén B')
# (495, 'Artículo495', 'Deportes', 224.63, 1, 'Proveedor2', '2023-04-21', 'Almacén A')
# (496, 'Producto496', 'Hogar', 151.75, 61, 'Proveedor3', '2023-02-28', 'Almacén B')
# (497, 'Artículo497', 'Deportes', 359.94, 45, 'Proveedor1', '2023-09-02', 'Almacén C')
# (498, 'Artículo498', 'Deportes', 394.35, 88, 'Proveedor1', '2023-07-28', 'Almacén B')
# (499, 'Artículo499', 'Deportes', 67.66, 23, 'Proveedor3', '2023-05-26', 'Almacén A')
# (500, 'Objeto500', 'Electrónica', 439.48, 74, 'Proveedor3', '2023-03-15', 'Almacén B')
# (501, 'Producto501', 'Hogar', 323.32, 15, 'Proveedor1', '2023-06-05', 'Almacén A')
# (502, 'Artículo502', 'Jardín', 239.43, 96, 'Proveedor3', '2023-04-11', 'Almacén A')
# (503, 'Objeto503', 'Deportes', 101.54, 9, 'Proveedor1', '2023-01-24', 'Almacén A')
# (504, 'Artículo504', 'Hogar', 92.3, 85, 'Proveedor1', '2023-11-04', 'Almacén C')
# (505, 'Artículo505', 'Jardín', 306.62, 5, 'Proveedor1', '2023-10-27', 'Almacén A')
# (506, 'Artículo506', 'Jardín', 139.03, 46, 'Proveedor3', '2023-04-28', 'Almacén A')
# (507, 'Producto507', 'Hogar', 22.28, 93, 'Proveedor1', '2023-05-01', 'Almacén B')
# (508, 'Producto508', 'Jardín', 163.63, 49, 'Proveedor3', '2023-10-08', 'Almacén C')
# (509, 'Objeto509', 'Deportes', 297.94, 65, 'Proveedor2', '2023-08-05', 'Almacén C')
# (510, 'Producto510', 'Jardín', 322.86, 77, 'Proveedor1', '2023-09-19', 'Almacén C')
# (511, 'Artículo511', 'Electrónica', 352.51, 67, 'Proveedor1', '2023-09-07', 'Almacén C')
# (512, 'Artículo512', 'Deportes', 37.78, 25, 'Proveedor3', '2023-08-25', 'Almacén B')
# (513, 'Producto513', 'Jardín', 91.97, 35, 'Proveedor1', '2023-02-13', 'Almacén B')
# (514, 'Objeto514', 'Moda', 478.53, 7, 'Proveedor2', '2023-06-03', 'Almacén C')
# (515, 'Objeto515', 'Hogar', 371.36, 5, 'Proveedor3', '2023-03-23', 'Almacén A')
# (516, 'Artículo516', 'Jardín', 41.25, 95, 'Proveedor1', '2023-04-23', 'Almacén B')
# (517, 'Objeto517', 'Jardín', 189.08, 11, 'Proveedor3', '2023-04-02', 'Almacén A')
# (518, 'Producto518', 'Electrónica', 138.47, 37, 'Proveedor2', '2023-09-03', 'Almacén C')
# (519, 'Artículo519', 'Jardín', 28.75, 20, 'Proveedor1', '2023-09-08', 'Almacén B')
# (520, 'Artículo520', 'Deportes', 68.61, 54, 'Proveedor1', '2023-12-24', 'Almacén C')
# (521, 'Objeto521', 'Jardín', 495.89, 17, 'Proveedor1', '2023-11-15', 'Almacén B')
# (522, 'Objeto522', 'Deportes', 17.17, 5, 'Proveedor2', '2023-07-15', 'Almacén A')
# (523, 'Objeto523', 'Jardín', 337.39, 8, 'Proveedor1', '2023-09-10', 'Almacén C')
# (524, 'Artículo524', 'Moda', 267.25, 40, 'Proveedor3', '2023-08-16', 'Almacén A')
# (525, 'Objeto525', 'Hogar', 150.11, 20, 'Proveedor2', '2023-06-25', 'Almacén B')
# (526, 'Objeto526', 'Deportes', 58.97, 49, 'Proveedor2', '2023-11-03', 'Almacén A')
# (527, 'Artículo527', 'Electrónica', 295.71, 56, 'Proveedor2', '2023-11-28', 'Almacén A')
# (528, 'Producto528', 'Hogar', 258.87, 70, 'Proveedor3', '2023-02-20', 'Almacén A')
# (529, 'Producto529', 'Moda', 322.77, 22, 'Proveedor3', '2023-11-21', 'Almacén B')
# (530, 'Artículo530', 'Moda', 259.03, 90, 'Proveedor3', '2023-12-01', 'Almacén A')
# (531, 'Objeto531', 'Electrónica', 334.26, 78, 'Proveedor3', '2023-12-04', 'Almacén C')
# (532, 'Producto532', 'Electrónica', 344.75, 35, 'Proveedor2', '2023-11-14', 'Almacén C')
# (533, 'Producto533', 'Moda', 65.72, 64, 'Proveedor1', '2023-08-21', 'Almacén A')
# (534, 'Producto534', 'Jardín', 460.55, 18, 'Proveedor2', '2023-07-03', 'Almacén A')
# (535, 'Objeto535', 'Hogar', 235.42, 61, 'Proveedor2', '2023-09-16', 'Almacén B')
# (536, 'Objeto536', 'Hogar', 173.57, 90, 'Proveedor2', '2023-03-04', 'Almacén C')
# (537, 'Artículo537', 'Jardín', 69.98, 59, 'Proveedor3', '2023-10-26', 'Almacén C')
# (538, 'Artículo538', 'Hogar', 299.98, 22, 'Proveedor1', '2023-01-25', 'Almacén B')
# (539, 'Artículo539', 'Jardín', 429.08, 94, 'Proveedor2', '2023-02-16', 'Almacén C')
# (540, 'Producto540', 'Jardín', 41.38, 82, 'Proveedor2', '2023-02-18', 'Almacén C')
# (541, 'Producto541', 'Jardín', 406.43, 92, 'Proveedor1', '2023-12-24', 'Almacén B')
# (542, 'Objeto542', 'Electrónica', 453.84, 34, 'Proveedor1', '2023-10-20', 'Almacén B')
# (543, 'Artículo543', 'Electrónica', 308.54, 68, 'Proveedor3', '2023-08-18', 'Almacén C')
# (544, 'Producto544', 'Deportes', 108.94, 58, 'Proveedor3', '2023-01-04', 'Almacén C')
# (545, 'Objeto545', 'Hogar', 49.09, 10, 'Proveedor3', '2023-12-10', 'Almacén B')
# (546, 'Artículo546', 'Hogar', 329, 45, 'Proveedor3', '2023-10-11', 'Almacén B')
# (547, 'Objeto547', 'Moda', 268.47, 20, 'Proveedor1', '2023-09-28', 'Almacén A')
# (548, 'Objeto548', 'Deportes', 498.84, 91, 'Proveedor3', '2023-10-09', 'Almacén C')
# (549, 'Producto549', 'Hogar', 27.21, 4, 'Proveedor2', '2023-03-28', 'Almacén A')
# (550, 'Objeto550', 'Hogar', 206.33, 85, 'Proveedor1', '2023-10-06', 'Almacén A')
# (551, 'Objeto551', 'Electrónica', 165.29, 28, 'Proveedor3', '2023-12-11', 'Almacén B')
# (552, 'Producto552', 'Hogar', 328.81, 9, 'Proveedor1', '2023-07-24', 'Almacén C')
# (553, 'Objeto553', 'Deportes', 13.62, 2, 'Proveedor1', '2023-07-09', 'Almacén B')
# (554, 'Producto554', 'Deportes', 27.92, 63, 'Proveedor3', '2023-08-18', 'Almacén B')
# (555, 'Objeto555', 'Hogar', 24.06, 38, 'Proveedor2', '2023-04-05', 'Almacén A')
# (556, 'Producto556', 'Hogar', 382.46, 15, 'Proveedor2', '2023-05-12', 'Almacén C')
# (557, 'Producto557', 'Jardín', 129.34, 6, 'Proveedor2', '2023-09-20', 'Almacén C')
# (558, 'Producto558', 'Electrónica', 381.83, 90, 'Proveedor3', '2023-05-18', 'Almacén A')
# (559, 'Artículo559', 'Electrónica', 314.52, 49, 'Proveedor2', '2023-08-21', 'Almacén B')
# (560, 'Producto560', 'Electrónica', 121.46, 35, 'Proveedor2', '2023-03-01', 'Almacén A')
# (561, 'Artículo561', 'Deportes', 367.94, 39, 'Proveedor2', '2023-02-15', 'Almacén B')
# (562, 'Producto562', 'Hogar', 274.98, 57, 'Proveedor1', '2023-02-17', 'Almacén B')
# (563, 'Producto563', 'Moda', 494.31, 81, 'Proveedor1', '2023-07-08', 'Almacén A')
# (564, 'Objeto564', 'Moda', 114.73, 18, 'Proveedor2', '2023-05-13', 'Almacén C')
# (565, 'Objeto565', 'Hogar', 265.09, 6, 'Proveedor2', '2023-03-03', 'Almacén A')
# (566, 'Artículo566', 'Hogar', 64.61, 61, 'Proveedor3', '2023-05-18', 'Almacén C')
# (567, 'Objeto567', 'Moda', 50.96, 28, 'Proveedor1', '2023-09-19', 'Almacén A')
# (568, 'Artículo568', 'Electrónica', 380.4, 50, 'Proveedor1', '2023-02-19', 'Almacén B')
# (569, 'Objeto569', 'Deportes', 138.67, 31, 'Proveedor3', '2023-02-08', 'Almacén A')
# (570, 'Objeto570', 'Moda', 220.72, 59, 'Proveedor1', '2023-02-06', 'Almacén A')
# (571, 'Artículo571', 'Electrónica', 462.24, 48, 'Proveedor2', '2023-04-08', 'Almacén C')
# (572, 'Objeto572', 'Jardín', 167.57, 23, 'Proveedor1', '2023-10-20', 'Almacén B')
# (573, 'Artículo573', 'Hogar', 42.71, 9, 'Proveedor2', '2023-01-28', 'Almacén A')
# (574, 'Objeto574', 'Hogar', 234.03, 12, 'Proveedor2', '2023-02-12', 'Almacén B')
# (575, 'Objeto575', 'Jardín', 235.81, 18, 'Proveedor1', '2023-06-04', 'Almacén B')
# (576, 'Producto576', 'Hogar', 214.9, 33, 'Proveedor3', '2023-02-03', 'Almacén C')
# ...
# (9814, 'Objeto9814', 'Deportes', 239.7, 27, 'Proveedor3', '2023-04-06', 'Almacén A')
# (9815, 'Artículo9815', 'Moda', 49.99, 72, 'Proveedor1', '2023-11-17', 'Almacén A')
# (9816, 'Producto9816', 'Electrónica', 420.63, 17, 'Proveedor2', '2023-07-03', 'Almacén B')
# (9817, 'Artículo9817', 'Moda', 231, 62, 'Proveedor1', '2023-07-06', 'Almacén A')
# (9818, 'Artículo9818', 'Electrónica', 456.32, 58, 'Proveedor1', '2023-05-24', 'Almacén C')
# (9819, 'Producto9819', 'Hogar', 148.69, 42, 'Proveedor3', '2023-03-23', 'Almacén C')
# (9820, 'Objeto9820', 'Hogar', 61.47, 44, 'Proveedor2', '2023-12-10', 'Almacén A')
# (9821, 'Objeto9821', 'Deportes', 453.85, 44, 'Proveedor2', '2023-04-23', 'Almacén A')
# (9822, 'Objeto9822', 'Hogar', 331.54, 84, 'Proveedor2', '2023-10-10', 'Almacén A')
# (9823, 'Producto9823', 'Hogar', 316.95, 25, 'Proveedor2', '2023-04-19', 'Almacén A')
# (9824, 'Objeto9824', 'Moda', 219.51, 13, 'Proveedor3', '2023-10-26', 'Almacén A')
# (9825, 'Artículo9825', 'Jardín', 242.32, 77, 'Proveedor1', '2023-04-03', 'Almacén B')
# (9826, 'Artículo9826', 'Deportes', 213.78, 86, 'Proveedor3', '2023-06-15', 'Almacén C')
# (9827, 'Producto9827', 'Deportes', 136.05, 31, 'Proveedor2', '2023-06-27', 'Almacén B')
# (9828, 'Artículo9828', 'Hogar', 146.79, 37, 'Proveedor3', '2023-12-20', 'Almacén C')
# (9829, 'Producto9829', 'Moda', 148.61, 58, 'Proveedor1', '2023-01-11', 'Almacén A')
# (9830, 'Objeto9830', 'Hogar', 112.08, 87, 'Proveedor2', '2023-09-03', 'Almacén A')
# (9831, 'Artículo9831', 'Hogar', 71.95, 74, 'Proveedor3', '2023-03-26', 'Almacén A')
# (9832, 'Producto9832', 'Jardín', 488.21, 31, 'Proveedor2', '2023-10-11', 'Almacén B')
# (9833, 'Producto9833', 'Moda', 468.22, 82, 'Proveedor1', '2023-05-16', 'Almacén A')
# (9834, 'Objeto9834', 'Deportes', 196.58, 64, 'Proveedor3', '2023-08-09', 'Almacén C')
# (9835, 'Artículo9835', 'Hogar', 43.07, 92, 'Proveedor3', '2023-11-18', 'Almacén B')
# (9836, 'Objeto9836', 'Electrónica', 224.96, 55, 'Proveedor3', '2023-08-15', 'Almacén B')
# (9837, 'Producto9837', 'Moda', 334.01, 56, 'Proveedor3', '2023-01-24', 'Almacén B')
# (9838, 'Objeto9838', 'Deportes', 221.57, 27, 'Proveedor3', '2023-07-23', 'Almacén A')
# (9839, 'Producto9839', 'Deportes', 147.95, 78, 'Proveedor2', '2023-10-06', 'Almacén C')
# (9840, 'Artículo9840', 'Hogar', 274.85, 42, 'Proveedor3', '2023-03-21', 'Almacén B')
# (9841, 'Producto9841', 'Electrónica', 29.16, 91, 'Proveedor1', '2023-02-04', 'Almacén A')
# (9842, 'Artículo9842', 'Jardín', 83.51, 15, 'Proveedor1', '2023-08-26', 'Almacén B')
# (9843, 'Producto9843', 'Hogar', 370.41, 30, 'Proveedor3', '2023-03-18', 'Almacén A')
# (9844, 'Producto9844', 'Electrónica', 20.06, 8, 'Proveedor1', '2023-05-09', 'Almacén C')
# (9845, 'Objeto9845', 'Jardín', 59.59, 19, 'Proveedor1', '2023-12-14', 'Almacén A')
# (9846, 'Producto9846', 'Hogar', 385.19, 1, 'Proveedor1', '2023-07-10', 'Almacén C')
# (9847, 'Producto9847', 'Moda', 225.41, 35, 'Proveedor2', '2023-09-28', 'Almacén A')
# (9848, 'Objeto9848', 'Hogar', 95.28, 54, 'Proveedor3', '2023-05-26', 'Almacén B')
# (9849, 'Artículo9849', 'Jardín', 247.01, 6, 'Proveedor2', '2023-06-16', 'Almacén A')
# (9850, 'Objeto9850', 'Deportes', 250.39, 6, 'Proveedor1', '2023-09-26', 'Almacén A')
# (9851, 'Producto9851', 'Jardín', 195.28, 76, 'Proveedor1', '2023-03-12', 'Almacén A')
# (9852, 'Producto9852', 'Moda', 407.24, 12, 'Proveedor2', '2023-09-19', 'Almacén B')
# (9853, 'Producto9853', 'Deportes', 255.31, 69, 'Proveedor1', '2023-02-23', 'Almacén C')
# (9854, 'Artículo9854', 'Deportes', 148.27, 71, 'Proveedor2', '2023-03-17', 'Almacén A')
# (9855, 'Producto9855', 'Electrónica', 375.16, 76, 'Proveedor2', '2023-02-10', 'Almacén C')
# (9856, 'Producto9856', 'Hogar', 437.45, 39, 'Proveedor1', '2023-12-01', 'Almacén B')
# (9857, 'Objeto9857', 'Deportes', 251.77, 88, 'Proveedor2', '2023-06-11', 'Almacén C')
# (9858, 'Producto9858', 'Moda', 245.56, 97, 'Proveedor1', '2023-06-10', 'Almacén B')
# (9859, 'Producto9859', 'Deportes', 56.78, 56, 'Proveedor1', '2023-11-18', 'Almacén A')
# (9860, 'Producto9860', 'Moda', 363.3, 26, 'Proveedor2', '2023-04-16', 'Almacén C')
# (9861, 'Producto9861', 'Electrónica', 434.07, 59, 'Proveedor3', '2023-01-02', 'Almacén A')
# (9862, 'Artículo9862', 'Deportes', 18.93, 49, 'Proveedor3', '2023-11-14', 'Almacén C')
# (9863, 'Objeto9863', 'Jardín', 94.62, 12, 'Proveedor2', '2023-10-22', 'Almacén B')
# (9864, 'Objeto9864', 'Electrónica', 477.41, 98, 'Proveedor3', '2023-06-28', 'Almacén C')
# (9865, 'Artículo9865', 'Jardín', 418.41, 83, 'Proveedor3', '2023-04-23', 'Almacén C')
# (9866, 'Objeto9866', 'Moda', 464.39, 97, 'Proveedor2', '2023-01-10', 'Almacén B')
# (9867, 'Producto9867', 'Jardín', 205.7, 51, 'Proveedor1', '2023-05-18', 'Almacén B')
# (9868, 'Artículo9868', 'Moda', 46.81, 2, 'Proveedor1', '2023-01-07', 'Almacén A')
# (9869, 'Objeto9869', 'Hogar', 326.74, 96, 'Proveedor2', '2023-11-10', 'Almacén A')
# (9870, 'Objeto9870', 'Hogar', 265.78, 71, 'Proveedor3', '2023-07-08', 'Almacén A')
# (9871, 'Artículo9871', 'Hogar', 28.94, 58, 'Proveedor1', '2023-12-03', 'Almacén A')
# (9872, 'Producto9872', 'Electrónica', 454.94, 59, 'Proveedor2', '2023-02-09', 'Almacén A')
# (9873, 'Artículo9873', 'Moda', 262.69, 43, 'Proveedor3', '2023-05-09', 'Almacén C')
# (9874, 'Producto9874', 'Moda', 174.74, 12, 'Proveedor2', '2023-10-28', 'Almacén B')
# (9875, 'Objeto9875', 'Jardín', 434.4, 72, 'Proveedor1', '2023-01-25', 'Almacén C')
# (9876, 'Objeto9876', 'Deportes', 185.87, 42, 'Proveedor1', '2023-12-28', 'Almacén A')
# (9877, 'Artículo9877', 'Hogar', 356.71, 42, 'Proveedor3', '2023-07-19', 'Almacén A')
# (9878, 'Producto9878', 'Deportes', 486.83, 91, 'Proveedor1', '2023-05-27', 'Almacén B')
# (9879, 'Producto9879', 'Moda', 390.68, 88, 'Proveedor1', '2023-07-25', 'Almacén C')
# (9880, 'Producto9880', 'Deportes', 276.24, 43, 'Proveedor2', '2023-04-25', 'Almacén C')
# (9881, 'Artículo9881', 'Hogar', 295.96, 80, 'Proveedor1', '2023-02-22', 'Almacén B')
# (9882, 'Objeto9882', 'Hogar', 353.83, 49, 'Proveedor3', '2023-10-09', 'Almacén B')
# (9883, 'Producto9883', 'Jardín', 13.28, 64, 'Proveedor1', '2023-10-15', 'Almacén C')
# (9884, 'Producto9884', 'Deportes', 193.55, 4, 'Proveedor2', '2023-05-21', 'Almacén C')
# (9885, 'Objeto9885', 'Electrónica', 331.43, 99, 'Proveedor2', '2023-03-05', 'Almacén A')
# (9886, 'Objeto9886', 'Hogar', 121.29, 5, 'Proveedor3', '2023-08-24', 'Almacén C')
# (9887, 'Artículo9887', 'Hogar', 160.13, 73, 'Proveedor3', '2023-10-25', 'Almacén B')
# (9888, 'Producto9888', 'Deportes', 344.04, 46, 'Proveedor3', '2023-01-19', 'Almacén C')
# (9889, 'Objeto9889', 'Hogar', 235.33, 17, 'Proveedor1', '2023-02-06', 'Almacén B')
# (9890, 'Producto9890', 'Electrónica', 164.9, 54, 'Proveedor1', '2023-01-04', 'Almacén B')
# (9891, 'Producto9891', 'Hogar', 368.39, 1, 'Proveedor2', '2023-07-15', 'Almacén B')
# (9892, 'Producto9892', 'Jardín', 393, 36, 'Proveedor3', '2023-10-23', 'Almacén B')
# (9893, 'Producto9893', 'Moda', 427.07, 22, 'Proveedor2', '2023-03-11', 'Almacén C')
# (9894, 'Producto9894', 'Electrónica', 376.66, 32, 'Proveedor1', '2023-12-20', 'Almacén C')
# (9895, 'Producto9895', 'Jardín', 294.12, 83, 'Proveedor1', '2023-11-20', 'Almacén C')
# (9896, 'Artículo9896', 'Deportes', 62.16, 19, 'Proveedor1', '2023-07-20', 'Almacén C')
# (9897, 'Objeto9897', 'Moda', 389.3, 67, 'Proveedor3', '2023-01-20', 'Almacén B')
# (9898, 'Objeto9898', 'Electrónica', 462.54, 43, 'Proveedor1', '2023-04-07', 'Almacén B')
# (9899, 'Producto9899', 'Hogar', 91.96, 83, 'Proveedor1', '2023-04-27', 'Almacén B')
# (9900, 'Objeto9900', 'Moda', 19.39, 87, 'Proveedor3', '2023-01-26', 'Almacén B')
# (9901, 'Producto9901', 'Electrónica', 303.05, 84, 'Proveedor2', '2023-02-06', 'Almacén A')
# (9902, 'Objeto9902', 'Jardín', 364.37, 88, 'Proveedor3', '2023-02-21', 'Almacén A')
# (9903, 'Artículo9903', 'Electrónica', 69.19, 41, 'Proveedor3', '2023-11-04', 'Almacén C')
# (9904, 'Producto9904', 'Hogar', 272.58, 88, 'Proveedor1', '2023-12-09', 'Almacén C')
# (9905, 'Artículo9905', 'Jardín', 481.03, 14, 'Proveedor2', '2023-01-15', 'Almacén A')
# (9906, 'Objeto9906', 'Deportes', 71.67, 50, 'Proveedor3', '2023-03-15', 'Almacén B')
# (9907, 'Producto9907', 'Electrónica', 233.22, 70, 'Proveedor3', '2023-07-16', 'Almacén B')
# (9908, 'Producto9908', 'Jardín', 335.81, 70, 'Proveedor2', '2023-03-19', 'Almacén A')
# (9909, 'Objeto9909', 'Moda', 286.69, 69, 'Proveedor1', '2023-12-22', 'Almacén C')
# (9910, 'Objeto9910', 'Hogar', 385.31, 31, 'Proveedor2', '2023-04-05', 'Almacén C')
# (9911, 'Producto9911', 'Deportes', 23.08, 35, 'Proveedor1', '2023-07-16', 'Almacén A')
# (9912, 'Artículo9912', 'Jardín', 263.62, 100, 'Proveedor3', '2023-06-27', 'Almacén A')
# (9913, 'Producto9913', 'Deportes', 477.43, 77, 'Proveedor2', '2023-09-03', 'Almacén B')
# (9914, 'Objeto9914', 'Electrónica', 98.96, 37, 'Proveedor2', '2023-07-02', 'Almacén A')
# (9915, 'Producto9915', 'Jardín', 400.02, 100, 'Proveedor1', '2023-10-15', 'Almacén C')
# (9916, 'Producto9916', 'Moda', 415.83, 31, 'Proveedor3', '2023-05-13', 'Almacén B')
# (9917, 'Producto9917', 'Moda', 372.31, 31, 'Proveedor2', '2023-07-02', 'Almacén A')
# (9918, 'Artículo9918', 'Deportes', 306.32, 20, 'Proveedor1', '2023-11-18', 'Almacén C')
# (9919, 'Producto9919', 'Electrónica', 160.34, 73, 'Proveedor2', '2023-08-25', 'Almacén B')
# (9920, 'Artículo9920', 'Deportes', 362.75, 57, 'Proveedor3', '2023-02-17', 'Almacén A')
# (9921, 'Objeto9921', 'Deportes', 457.23, 72, 'Proveedor3', '2023-11-19', 'Almacén B')
# (9922, 'Artículo9922', 'Electrónica', 476.47, 64, 'Proveedor2', '2023-10-07', 'Almacén C')
# (9923, 'Objeto9923', 'Hogar', 418.26, 5, 'Proveedor3', '2023-12-06', 'Almacén C')
# (9924, 'Artículo9924', 'Electrónica', 418, 48, 'Proveedor3', '2023-06-05', 'Almacén B')
# (9925, 'Producto9925', 'Electrónica', 91.79, 33, 'Proveedor2', '2023-08-15', 'Almacén C')
# (9926, 'Producto9926', 'Hogar', 440.4, 43, 'Proveedor1', '2023-04-26', 'Almacén B')
# (9927, 'Objeto9927', 'Deportes', 87.31, 75, 'Proveedor2', '2023-02-21', 'Almacén B')
# (9928, 'Objeto9928', 'Electrónica', 50.73, 5, 'Proveedor3', '2023-01-10', 'Almacén C')
# (9929, 'Objeto9929', 'Deportes', 300.66, 35, 'Proveedor2', '2023-03-22', 'Almacén C')
# (9930, 'Objeto9930', 'Deportes', 281.12, 44, 'Proveedor3', '2023-09-21', 'Almacén A')
# (9931, 'Artículo9931', 'Deportes', 322.36, 34, 'Proveedor3', '2023-08-07', 'Almacén B')
# (9932, 'Artículo9932', 'Electrónica', 151.38, 62, 'Proveedor1', '2023-11-06', 'Almacén A')
# (9933, 'Objeto9933', 'Moda', 354.33, 25, 'Proveedor3', '2023-07-12', 'Almacén C')
# (9934, 'Producto9934', 'Electrónica', 246.56, 79, 'Proveedor2', '2023-12-07', 'Almacén B')
# (9935, 'Objeto9935', 'Jardín', 379.28, 29, 'Proveedor3', '2023-08-14', 'Almacén C')
# (9936, 'Producto9936', 'Moda', 493.1, 90, 'Proveedor2', '2023-11-18', 'Almacén B')
# (9937, 'Objeto9937', 'Jardín', 464.43, 51, 'Proveedor3', '2023-06-24', 'Almacén B')
# (9938, 'Artículo9938', 'Jardín', 444.76, 79, 'Proveedor1', '2023-06-09', 'Almacén C')
# (9939, 'Artículo9939', 'Deportes', 401.68, 69, 'Proveedor1', '2023-01-13', 'Almacén B')
# (9940, 'Objeto9940', 'Electrónica', 334.5, 78, 'Proveedor3', '2023-10-11', 'Almacén B')
# (9941, 'Objeto9941', 'Moda', 72.2, 76, 'Proveedor1', '2023-01-27', 'Almacén B')
# (9942, 'Producto9942', 'Hogar', 360.78, 60, 'Proveedor1', '2023-07-03', 'Almacén C')
# (9943, 'Artículo9943', 'Electrónica', 324.75, 82, 'Proveedor1', '2023-05-24', 'Almacén B')
# (9944, 'Objeto9944', 'Electrónica', 491.2, 92, 'Proveedor2', '2023-04-26', 'Almacén C')
# (9945, 'Objeto9945', 'Moda', 84.43, 77, 'Proveedor2', '2023-02-17', 'Almacén B')
# (9946, 'Objeto9946', 'Electrónica', 475.96, 63, 'Proveedor3', '2023-06-04', 'Almacén A')
# (9947, 'Artículo9947', 'Moda', 176.14, 94, 'Proveedor3', '2023-04-24', 'Almacén B')
# (9948, 'Artículo9948', 'Hogar', 24.84, 47, 'Proveedor3', '2023-01-22', 'Almacén A')
# (9949, 'Producto9949', 'Jardín', 109.53, 38, 'Proveedor3', '2023-05-26', 'Almacén A')
# (9950, 'Artículo9950', 'Deportes', 34.55, 91, 'Proveedor1', '2023-11-07', 'Almacén A')
# (9951, 'Artículo9951', 'Hogar', 350.27, 19, 'Proveedor2', '2023-07-07', 'Almacén C')
# (9952, 'Producto9952', 'Moda', 373.66, 12, 'Proveedor1', '2023-02-18', 'Almacén B')
# (9953, 'Objeto9953', 'Hogar', 153.22, 32, 'Proveedor3', '2023-05-24', 'Almacén A')
# (9954, 'Producto9954', 'Electrónica', 433.89, 43, 'Proveedor1', '2023-10-25', 'Almacén C')
# (9955, 'Producto9955', 'Jardín', 474.95, 22, 'Proveedor1', '2023-06-15', 'Almacén C')
# (9956, 'Objeto9956', 'Electrónica', 467.6, 97, 'Proveedor1', '2023-12-24', 'Almacén B')
# (9957, 'Artículo9957', 'Electrónica', 29.1, 41, 'Proveedor3', '2023-08-19', 'Almacén A')
# (9958, 'Objeto9958', 'Jardín', 240.78, 79, 'Proveedor3', '2023-12-23', 'Almacén B')
# (9959, 'Objeto9959', 'Electrónica', 245.78, 31, 'Proveedor2', '2023-01-09', 'Almacén A')
# (9960, 'Objeto9960', 'Moda', 414.83, 29, 'Proveedor3', '2023-07-15', 'Almacén C')
# (9961, 'Objeto9961', 'Deportes', 432.66, 50, 'Proveedor3', '2023-04-24', 'Almacén B')
# (9962, 'Objeto9962', 'Hogar', 424.3, 3, 'Proveedor1', '2023-01-14', 'Almacén B')
# (9963, 'Objeto9963', 'Hogar', 491.83, 82, 'Proveedor2', '2023-03-09', 'Almacén A')
# (9964, 'Artículo9964', 'Electrónica', 288.86, 56, 'Proveedor1', '2023-01-11', 'Almacén B')
# (9965, 'Artículo9965', 'Jardín', 441.66, 54, 'Proveedor1', '2023-11-24', 'Almacén C')
# (9966, 'Objeto9966', 'Moda', 341.65, 62, 'Proveedor1', '2023-02-03', 'Almacén B')
# (9967, 'Artículo9967', 'Jardín', 128.8, 10, 'Proveedor2', '2023-12-15', 'Almacén B')
# (9968, 'Producto9968', 'Deportes', 413.41, 5, 'Proveedor2', '2023-07-12', 'Almacén A')
# (9969, 'Producto9969', 'Moda', 365.79, 84, 'Proveedor2', '2023-10-07', 'Almacén B')
# (9970, 'Artículo9970', 'Moda', 264.65, 4, 'Proveedor1', '2023-11-15', 'Almacén A')
# (9971, 'Objeto9971', 'Electrónica', 462.41, 5, 'Proveedor3', '2023-01-04', 'Almacén A')
# (9972, 'Artículo9972', 'Hogar', 184.9, 70, 'Proveedor1', '2023-02-14', 'Almacén C')
# (9973, 'Producto9973', 'Jardín', 332.44, 73, 'Proveedor2', '2023-08-23', 'Almacén B')
# (9974, 'Producto9974', 'Moda', 215.49, 47, 'Proveedor1', '2023-10-03', 'Almacén A')
# (9975, 'Objeto9975', 'Jardín', 20.09, 71, 'Proveedor2', '2023-08-17', 'Almacén A')
# (9976, 'Artículo9976', 'Deportes', 82.04, 22, 'Proveedor2', '2023-09-25', 'Almacén B')
# (9977, 'Artículo9977', 'Jardín', 188.86, 49, 'Proveedor2', '2023-05-15', 'Almacén C')
# (9978, 'Objeto9978', 'Moda', 91.51, 26, 'Proveedor1', '2023-01-08', 'Almacén B')
# (9979, 'Artículo9979', 'Jardín', 163.93, 12, 'Proveedor2', '2023-03-26', 'Almacén C')
# (9980, 'Objeto9980', 'Electrónica', 423.25, 4, 'Proveedor3', '2023-05-25', 'Almacén B')
# (9981, 'Producto9981', 'Jardín', 279.04, 92, 'Proveedor1', '2023-08-07', 'Almacén A')
# (9982, 'Objeto9982', 'Moda', 292, 10, 'Proveedor2', '2023-12-24', 'Almacén A')
# (9983, 'Objeto9983', 'Jardín', 334.81, 76, 'Proveedor2', '2023-03-04', 'Almacén A')
# (9984, 'Objeto9984', 'Moda', 63.26, 50, 'Proveedor1', '2023-02-17', 'Almacén A')
# (9985, 'Artículo9985', 'Moda', 172.61, 58, 'Proveedor3', '2023-10-03', 'Almacén C')
# (9986, 'Producto9986', 'Hogar', 132.39, 33, 'Proveedor1', '2023-06-22', 'Almacén C')
# (9987, 'Producto9987', 'Hogar', 14.78, 7, 'Proveedor1', '2023-11-26', 'Almacén C')
# (9988, 'Objeto9988', 'Deportes', 401.44, 14, 'Proveedor3', '2023-07-18', 'Almacén B')
# (9989, 'Artículo9989', 'Hogar', 42.59, 84, 'Proveedor2', '2023-02-11', 'Almacén A')
# (9990, 'Producto9990', 'Hogar', 62.5, 38, 'Proveedor2', '2023-06-07', 'Almacén C')
# (9991, 'Objeto9991', 'Moda', 371.14, 41, 'Proveedor3', '2023-12-24', 'Almacén C')
# (9992, 'Objeto9992', 'Jardín', 357.34, 74, 'Proveedor1', '2023-09-18', 'Almacén A')
# (9993, 'Artículo9993', 'Jardín', 259.01, 67, 'Proveedor3', '2023-10-21', 'Almacén B')
# (9994, 'Objeto9994', 'Moda', 230.93, 12, 'Proveedor3', '2023-07-14', 'Almacén C')
# (9995, 'Producto9995', 'Jardín', 463.44, 18, 'Proveedor1', '2023-11-20', 'Almacén B')
# (9996, 'Producto9996', 'Jardín', 23.8, 8, 'Proveedor1', '2023-08-13', 'Almacén B')
# (9997, 'Artículo9997', 'Moda', 486.27, 12, 'Proveedor2', '2023-07-18', 'Almacén A')
# (9998, 'Artículo9998', 'Deportes', 432.16, 37, 'Proveedor3', '2023-12-04', 'Almacén B')
# (9999, 'Artículo9999', 'Electrónica', 126.25, 84, 'Proveedor2', '2023-11-23', 'Almacén A')
# (10000, 'Objeto10000', 'Moda', 202.55, 85, 'Proveedor1', '2023-01-23', 'Almacén C')

# %% [markdown]
# ## Realizar consulta y transferir a dataframe

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)

# Cerrar la conexión
conn.close()
# Out:
#         id        nombre    categoria  precio  cantidad   proveedor  \
# 0        3     Artículo3        Hogar  451.54        26  Proveedor2
# 1        8     Producto8     Deportes  485.50        70  Proveedor3
# 2       11    Producto11         Moda  468.67         2  Proveedor2
# 3       13    Producto13         Moda  495.97         1  Proveedor3
# 4       18      Objeto18        Hogar  484.41        31  Proveedor3
# ...    ...           ...          ...     ...       ...         ...
# 996   9956    Objeto9956  Electrónica  467.60        97  Proveedor1
# 997   9963    Objeto9963        Hogar  491.83        82  Proveedor2
# 998   9971    Objeto9971  Electrónica  462.41         5  Proveedor3
# 999   9995  Producto9995       Jardín  463.44        18  Proveedor1
# 1000  9997  Artículo9997         Moda  486.27        12  Proveedor2
#
#      fecha_ingreso  ubicacion
# 0       2023-11-25  Almacén C
# 1       2023-09-17  Almacén C
# 2       2023-08-13  Almacén C
# 3       2023-03-03  Almacén A
# 4       2023-04-25  Almacén C
# ...            ...        ...
# 996     2023-12-24  Almacén B
# 997     2023-03-09  Almacén A
# 998     2023-01-04  Almacén A
# 999     2023-11-20  Almacén B
# 1000    2023-07-18  Almacén A
#
# [1001 rows x 8 columns]

# %%
df_productos.head()
# Out:
#    id      nombre categoria  precio  cantidad   proveedor fecha_ingreso  \
# 0   3   Artículo3     Hogar  451.54        26  Proveedor2    2023-11-25
# 1   8   Producto8  Deportes  485.50        70  Proveedor3    2023-09-17
# 2  11  Producto11      Moda  468.67         2  Proveedor2    2023-08-13
# 3  13  Producto13      Moda  495.97         1  Proveedor3    2023-03-03
# 4  18    Objeto18     Hogar  484.41        31  Proveedor3    2023-04-25
#
#    ubicacion
# 0  Almacén C
# 1  Almacén C
# 2  Almacén C
# 3  Almacén A
# 4  Almacén C

# %% [markdown]
# ## Nueva consulta

# %%
import sqlite3
import pandas as pd

# Conectar a la base de datos
conn = sqlite3.connect('productos.db')

# Realizar la consulta y cargar los resultados en un DataFrame
query = "SELECT * FROM inventario WHERE precio > 450 AND cantidad > 25"
df_productos = pd.read_sql_query(query, conn)

# Mostrar el DataFrame
print(df_productos)


# Cerrar la conexión
conn.close()
# Out:
#        id      nombre    categoria  precio  cantidad   proveedor  \
# 0       3   Artículo3        Hogar  451.54        26  Proveedor2
# 1       8   Producto8     Deportes  485.50        70  Proveedor3
# 2      18    Objeto18        Hogar  484.41        31  Proveedor3
# 3      34  Producto34         Moda  467.65        83  Proveedor3
# 4      41    Objeto41         Moda  452.91        28  Proveedor3
# ..    ...         ...          ...     ...       ...         ...
# 721  9937  Objeto9937       Jardín  464.43        51  Proveedor3
# 722  9944  Objeto9944  Electrónica  491.20        92  Proveedor2
# 723  9946  Objeto9946  Electrónica  475.96        63  Proveedor3
# 724  9956  Objeto9956  Electrónica  467.60        97  Proveedor1
# 725  9963  Objeto9963        Hogar  491.83        82  Proveedor2
#
#     fecha_ingreso  ubicacion
# 0      2023-11-25  Almacén C
# 1      2023-09-17  Almacén C
# 2      2023-04-25  Almacén C
# 3      2023-12-10  Almacén C
# 4      2023-09-10  Almacén C
# ..            ...        ...
# 721    2023-06-24  Almacén B
# 722    2023-04-26  Almacén C
# 723    2023-06-04  Almacén A
# 724    2023-12-24  Almacén B
# 725    2023-03-09  Almacén A
#
# [726 rows x 8 columns]

# %% [markdown]
# ## Insertar nuevo producto

# %%
# Datos del nuevo producto
nuevo_producto = (
    None,  # SQLite genera un nuevo id automáticamente si la columna es autoincrement
    'NuevoProducto123',
    'Electrónica',
    249.99,
    20,
    'ProveedorX',
    '2024-04-16',
    'Almacén D'
)

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de nuevo producto
c.execute('INSERT INTO inventario VALUES (?, ?, ?, ?, ?, ?, ?, ?)', nuevo_producto)

# Guardar (commit) los cambios y cerrar conexión con la DB
conn.commit()
conn.close()

# %% [markdown]
# ## Insertar nuevo producto desde Excel

# %% [markdown]
# ### Crear tabla excel de nuevos productos

# %%
import pandas as pd
import numpy as np
from datetime import datetime, timedelta

np.random.seed(0)
num_prods = 5000

# Productos nuevos
nombres = ['Producto' + str(i) for i in range(num_prods)]
categorias = np.random.choice(['Electrónica', 'Hogar', 'Jardín', 'Moda', 'Deportes'], num_prods)
precios = np.round(np.random.uniform(10.0, 500.0, num_prods), 2)
cantidades = np.random.randint(1, 100, num_prods)
proveedores = np.random.choice(['Proveedor1', 'Proveedor2', 'Proveedor3'], num_prods)
fechas = [datetime.today() - timedelta(days=np.random.randint(0, 365)) for _ in range(num_prods)]
ubicaciones = np.random.choice(['Almacén A', 'Almacén B', 'Almacén C'], num_prods)

# DataFrame
df = pd.DataFrame({
    'Nombre': nombres,
    'Categoría': categorias,
    'Precio': precios,
    'Cantidad': cantidades,
    'Proveedor': proveedores,
    'Fecha de Ingreso': pd.to_datetime(fechas),
    'Ubicación': ubicaciones
})

print(df.head())

# Guardar el DataFrame en un archivo Excel
df.to_excel('nuevos_productos_inventario.xlsx', index=False)
# Out:
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#             Fecha de Ingreso  Ubicación
# 0 2025-06-20 03:09:13.310890  Almacén B
# 1 2025-03-25 03:09:13.310931  Almacén C
# 2 2024-12-31 03:09:13.310941  Almacén B
# 3 2025-08-28 03:09:13.310949  Almacén A
# 4 2024-12-14 03:09:13.310956  Almacén A

# %% [markdown]
# ### Agregar datos de tabla excel al inventario

# %%
import pandas as pd

# Leer archivo Excel
ruta_archivo = '/content/nuevos_productos_inventario.xlsx'
df = pd.read_excel(ruta_archivo)

# Verificación de formatos (tipo de dato)
# Precio a float
if df['Precio'].dtype != 'float':
    df['Precio'] = df['Precio'].astype(float)

# Fecha de Ingreso a datetime
if df['Fecha de Ingreso'].dtype != 'datetime64[ns]':
    df['Fecha de Ingreso'] = pd.to_datetime(df['Fecha de Ingreso'], errors='coerce')

# Verificar y corregir fechas no válidas, usando la fecha de hoy
df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)

df.head()
# Out:
# /tmp/ipython-input-1041989223.py:17: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['Fecha de Ingreso'].fillna(pd.Timestamp.today(), inplace=True)
#       Nombre    Categoría  Precio  Cantidad   Proveedor  \
# 0  Producto0     Deportes  489.97        77  Proveedor1
# 1  Producto1  Electrónica  347.86        78  Proveedor3
# 2  Producto2         Moda   10.40        93  Proveedor2
# 3  Producto3         Moda  402.25        51  Proveedor3
# 4  Producto4         Moda  445.18        50  Proveedor1
#
#          Fecha de Ingreso  Ubicación
# 0 2025-06-20 03:09:13.311  Almacén B
# 1 2025-03-25 03:09:13.311  Almacén C
# 2 2024-12-31 03:09:13.311  Almacén B
# 3 2025-08-28 03:09:13.311  Almacén A
# 4 2024-12-14 03:09:13.311  Almacén A

# %%
# @title
import sqlite3

# Conexión con la DB
conn = sqlite3.connect('productos.db')
c = conn.cursor()

# Insersión de datos en la DB
for index, row in df.iterrows():
    c.execute("""
        INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
        VALUES (?, ?, ?, ?, ?, ?, ?)
    """, (row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']))


# # Insersión de datos en la DB
# for index, row in df.iterrows():
#     c.executemany("""
#         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#         VALUES(?, ?, ?, ?, ?, ?,)""",
#         [row['Nombre'], row['Categoría'], row['Precio'], row['Cantidad'], row['Proveedor'], row['Fecha de Ingreso'], row['Ubicación']])

# Guardar cambios y cerrar conexión con DB
conn.commit()
conn.close()

print("¡Datos importados exitosamente!")
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# /tmp/ipython-input-1685593635.py in <cell line: 0>()
#       7 # Insersión de datos en la DB
#       8 for index, row in df.iterrows():
# ----> 9     c.execute("""
#      10         INSERT INTO inventario (nombre, categoria, precio, cantidad, proveedor, fecha_ingreso, ubicacion)
#      11         VALUES (?, ?, ?, ?, ?, ?, ?)
#
# ProgrammingError: Error binding parameter 6: type 'Timestamp' is not supported

# %% [markdown]
# 1. El argumento especifica el nombre del archivo de la base de datos, Si hay un archivo existente en el directorio, sqlite3 va a crear una conexión con el, si no, sqlite3 creará automaticamente una nueva base de datos con ese nombre.
# 2. el argumento conn.cursor() crea un objeto "cursor" desde la conexión de la base de datos (conn), la cual actua como un puntero para manejar y ejecutar comandos de SQL dentro de una sesion de base de datos, Este puntero nos permite navegar en los datos de forma mas organizada.
# 3. Definir la columna como "Integer Primary Key" cumple dos cosas importantes, la primera es que garantiza que cada fila de la tabla tenga un valor único en esa columna (osea no se repiten) y además SQLite asigna automáticamente un número consecutivo a cada registro insertado, sin la necesesidad de que por el ejemplo el programador lo diga.
# 4. La ventaja principal de usar "executemany()" es que el envía todas las inserciones en un solo bloque a la base de datos, esto es mucho más rapido y consume menos rcursos que usando un bucle con "execute".{
# 5. Si omitimos el "coon.commit()" los datos no se guardaran realmente en nuestra base de datos, solo quedaria en la memoria temporal.

# %%
conn = sqlite3.connect('productos.db')

#Consulta SQL: solo los productos del Proveedor1
query = """
SELECT nombre, categoria, precio
FROM inventario
WHERE proveedor = 'Proveedor1'
"""

# Mostrar los resultados como tabla
df_proveedor1.head(20)  # puedes cambiar el número si quieres ver más filas

# Cerrar conexión
conn.close()

print(df_proveedor1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-3226973459.py in <cell line: 0>()
#       9
#      10 # Mostrar los resultados como tabla
# ---> 11 df_proveedor1.head(20)  # puedes cambiar el número si quieres ver más filas
#      12
#      13 # Cerrar conexión
#
# NameError: name 'df_proveedor1' is not defined

# %% [markdown]
# 7. Las ventajas que ofrece "pd.read_sql_query()" seria que convierte automáticamente los resultados que tenemos en un DataFrame de pandas, con eso nos permite analizarlos y verlos más facil y organizados, ademas evitamos recorrer los resultados manualmente como lo hariamos con un bucle como "for".

# %%
query = "SELECT * FROM inventario WHERE precio > 480 OR cantidad < 5"

# %% [markdown]
# 9. Usar los signos de interrogación es una buena práctica porque evita que los valores se concatenen directamente en SQL, además mejora la legibilidad y facilita la reutización del codigo.
# 10. Es fundamental porque garantiza que los datos tengan el tipo correcto en precios y fechas, si esto no se hace, puede generarse errores de tipo o inserciones incorrectas, lo que puede causar fallos en el futuro con la base de datos.
